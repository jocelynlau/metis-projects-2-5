# %% [markdown]
# #Hospital Compare - Readmission rates:
# #https://data.medicare.gov/Hospital-Compare/Hospital-Readmissions-Reduction-Program/9n3s-kdb3
#
# #Hospital Info (including addresses):
# #https://data.medicare.gov/Hospital-Compare/Hospital-General-Information/xubh-q36u
#
# #2017 Wage Index:
# #https://www.cms.gov/Medicare/Medicare-Fee-for-Service-Payment/AcuteInpatientPPS/Wage-Index-Files-Items/FY2017-Wage-Index-Home-Page.html?DLPage=1&DLEntries=10&DLSort=1&DLSortDir=descending
#
# #Census Data - median household income by county

# %% [markdown]
# ### Set up

# %%
from __future__ import print_function, division
#Import BeautifulSoup
from bs4 import BeautifulSoup
#Regular expressions compiler
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

import pickle

#import special dictionaries/functions from other programs
from us_state_abbrev import us_state_abbrev

# %%
# if needed: pip install requests or conda install requests
import requests

requests.__path__
# Out:
# ['/Users/Jocelyn/anaconda3/lib/python3.7/site-packages/requests']

# %% [markdown]
# ## import healthdata.gov datasets using API
# HRRP API info: https://dev.socrata.com/foundry/data.medicare.gov/9n3s-kdb3
# General Hospital API info: https://dev.socrata.com/foundry/data.medicare.gov/rbry-mqwu
#
# ONLY RUN AS NEEDED AS THERE ARE STRICT THROTTLING LIMITS WITHOUT TOKEN! USE THE PICKLES

# %%
#!/usr/bin/env python

# # make sure to install these packages before running:
# # pip install pandas
# # pip install sodapy

# import pandas as pd
# from sodapy import Socrata

# # Unauthenticated client only works with public data sets. Note 'None'
# # in place of application token, and no username or password:
# client = Socrata("data.medicare.gov", None)

# # Example authenticated client (needed for non-public datasets):
# # client = Socrata(data.medicare.gov,
# #                  MyAppToken,
# #                  userame="user@example.com",
# #                  password="AFakePassword")

# # Results returned as JSON from API / converted to Python list of
# # dictionaries by sodapy.
# hrrp = client.get("9n3s-kdb3", limit=20000) #Readmissions scores
# geninfo = client.get("rbry-mqwu", limit=6000) #General hospital information

# # Convert to pandas DataFrame
# hrrp_df = pd.DataFrame.from_records(hrrp)
# geninfo_df = pd.DataFrame.from_records(geninfo)

# %%
# #pickle the datasets for later use
# with open('hrrp.pickle', 'wb') as to_write:
#     pickle.dump(hrrp_df, to_write)

# with open('geninfo.pickle', 'wb') as to_write:
#     pickle.dump(geninfo_df, to_write)
    
# !ls

# %% [markdown]
# ## Import hospital wage index data

# %%
wageindex14 = pd.read_csv("wage_index_14.txt", delimiter = "\t",header=None,names=['CCN','Case_Mix_Indexes','FY_Wage_Index','Avg_Hourly_Wage_FY2012',
                                                                         'Avg_Hourly_Wage_FY2013','Avg_Hourly_Wage_FY2014','3_Year_Avg_Hourly_Wage'])

wageindex15 = pd.read_csv("wage_index_15.txt", delimiter = "\t",header=None,names=['CCN','Case_Mix_Indexes','FY_Wage_Index','Avg_Hourly_Wage_FY2013',
                                                                         'Avg_Hourly_Wage_FY2014','Avg_Hourly_Wage_FY2015','3_Year_Avg_Hourly_Wage'])
# wageindex14.info()

# %%
wageindex16 = pd.read_csv('wage_index_16.txt', delimiter = "\t",header=None,names=['CCN','Case_Mix_Indexes','FY_Wage_Index','Avg_Hourly_Wage_FY2014',
                                                                        'Avg_Hourly_Wage_FY2015','Avg_Hourly_Wage_FY2016','3_Year_Avg_Hourly_Wage',
                                                                        'Geographic_CBSA','Reclassified_Redesignated_CBSA','Lugar_NECMA','MGCRB_Reclass',
                                                                        'Hosp_Reclass','Out_Migration_Adj','County_Name','County_Code'])
wageindex17 = pd.read_csv('wage_index_17.txt', delimiter = "\t",header=None,names=['CCN','Case_Mix_Indexes','FY_Wage_Index','Avg_Hourly_Wage_FY2015',
                                                                        'Avg_Hourly_Wage_FY2016','Avg_Hourly_Wage_FY2017','3_Year_Avg_Hourly_Wage',
                                                                        'Geographic_CBSA','Reclassified_Redesignated_CBSA','Lugar_NECMA','MGCRB_Reclass',
                                                                        'Hosp_Reclass','Out_Migration_Adj','County_Name','County_Code'])
# wageindex16.info()

# %%
# local_path = "../../project 2/FY2017-NPRM-Tables-2-and-3/CMS 1655-P FY 2017 Proposed Rule Table 2.txt"
# local_path = "Users/Jocelyn/Metis/local projects/project 2/FY2017-NPRM-Tables-2-and-3/CMS 1655-P FY 2017 Proposed Rule Table 2.txt"
# local_path = "CMS 1655-P FY 2017 Proposed Rule Table 2_2.txt"
# wageindex = pd.read_csv(local_path, delimiter = "\t",header=None,names=['CCN','Case_Mix_Indexes','FY_2017_Wage_Index','Avg_Hourly_Wage_FY2015',
#                                                                         'Avg_Hourly_Wage_FY2016','Avg_Hourly_Wage_FY2017','3_Year_Avg_Hourly_Wage_15_16_17',
#                                                                         'Geographic_CBSA','Reclassified_Redesignated_CBSA','Lugar_NECMA','MGCRB_Reclass',
#                                                                         'Hosp_Reclass','Out_Migration_Adj','County_Name','County_Code'])
# wageindex.info()

with open('wageindex14.pickle', 'wb') as to_write:
    pickle.dump(wageindex14, to_write)
with open('wageindex15.pickle', 'wb') as to_write:
    pickle.dump(wageindex15, to_write)
with open('wageindex16.pickle', 'wb') as to_write:
    pickle.dump(wageindex16, to_write)
with open('wageindex17.pickle', 'wb') as to_write:
    pickle.dump(wageindex17, to_write)

# %% [markdown]
# ## Import county income data

# %%
censusincome14 = pd.read_csv('census_income_data_14.csv',skiprows=[0])
censusincome15 = pd.read_csv('census_income_data_15.csv',skiprows=[0])
censusincome16 = pd.read_csv('census_income_data_16.csv',skiprows=[0])
censusincome17 = pd.read_csv('census_income_data_17.csv',skiprows=[0])

# censusincome.info()
# censusincome17.head(5)

with open('censusincome14.pickle', 'wb') as to_write:
    pickle.dump(censusincome14, to_write)
with open('censusincome15.pickle', 'wb') as to_write:
    pickle.dump(censusincome15, to_write)
with open('censusincome16.pickle', 'wb') as to_write:
    pickle.dump(censusincome16, to_write)
with open('censusincome17.pickle', 'wb') as to_write:
    pickle.dump(censusincome17, to_write)

# %% [markdown]
# ## Import education

# %%
education = pd.read_csv('Education.csv')
# education.head(5)
education.info()

with open('education.pickle', 'wb') as to_write:
    pickle.dump(education, to_write)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3583 entries, 0 to 3582
# Data columns (total 48 columns):
# FIPS Code                                                                   3204 non-null float64
# State                                                                       3204 non-null object
# Area name                                                                   3204 non-null object
# 2003 Rural-urban Continuum Code                                             3143 non-null float64
# 2003 Urban Influence Code                                                   3143 non-null float64
# 2013 Rural-urban Continuum Code                                             3143 non-null float64
# 2013 Urban Influence Code                                                   3143 non-null float64
# Less than a high school diploma, 1970                                       3186 non-null object
# High school diploma only, 1970                                              3186 non-null object
# Some college (1-3 years), 1970                                              3186 non-null object
# Four years of college or higher, 1970                                       3186 non-null object
# Percent of adults with less than a high school diploma, 1970                3186 non-null float64
# Percent of adults with a high school diploma only, 1970                     3186 non-null float64
# Percent of adults completing some college (1-3 years), 1970                 3186 non-null float64
# Percent of adults completing four years of college or higher, 1970          3186 non-null float64
# Less than a high school diploma, 1980                                       3188 non-null object
# High school diploma only, 1980                                              3188 non-null object
# Some college (1-3 years), 1980                                              3188 non-null object
# Four years of college or higher, 1980                                       3188 non-null object
# Percent of adults with less than a high school diploma, 1980                3188 non-null float64
# Percent of adults with a high school diploma only, 1980                     3188 non-null float64
# Percent of adults completing some college (1-3 years), 1980                 3188 non-null float64
# Percent of adults completing four years of college or higher, 1980          3188 non-null float64
# Less than a high school diploma, 1990                                       3192 non-null object
# High school diploma only, 1990                                              3192 non-null object
# Some college or associate's degree, 1990                                    3192 non-null object
# Bachelor's degree or higher, 1990                                           3192 non-null object
# Percent of adults with less than a high school diploma, 1990                3192 non-null float64
# Percent of adults with a high school diploma only, 1990                     3192 non-null float64
# Percent of adults completing some college or associate's degree, 1990       3191 non-null float64
# Percent of adults with a bachelor's degree or higher, 1990                  3192 non-null float64
# Less than a high school diploma, 2000                                       3193 non-null object
# High school diploma only, 2000                                              3193 non-null object
# Some college or associate's degree, 2000                                    3193 non-null object
# Bachelor's degree or higher, 2000                                           3193 non-null object
# Percent of adults with less than a high school diploma, 2000                3193 non-null float64
# Percent of adults with a high school diploma only, 2000                     3193 non-null float64
# Percent of adults completing some college or associate's degree, 2000       3193 non-null float64
# Percent of adults with a bachelor's degree or higher, 2000                  3193 non-null float64
# Less than a high school diploma, 2013-17                                    3194 non-null object
# High school diploma only, 2013-17                                           3194 non-null object
# Some college or associate's degree, 2013-17                                 3194 non-null object
# Bachelor's degree or higher, 2013-17                                        3194 non-null object
# Percent of adults with less than a high school diploma, 2013-17             3194 non-null float64
# Percent of adults with a high school diploma only, 2013-17                  3194 non-null float64
# Percent of adults completing some college or associate's degree, 2013-17    3194 non-null float64
# Percent of adults with a bachelor's degree or higher, 2013-17               3194 non-null float64
# Unnamed: 47                                                                 0 non-null float64
# dtypes: float64(26), object(22)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Open pickled datasets

# %% [markdown]
# ### Hospital

# %%
with open('hrrp.pickle','rb') as read_file:
    hrrp_df = pickle.load(read_file)
    
hrrp_df.head(5)
# Out:
#                       hospital_name provider_id state            measure_name  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL       READM_30_AMI_HRRP
# 1  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL      READM_30_CABG_HRRP
# 2  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL      READM_30_COPD_HRRP
# 3  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL        READM_30_HF_HRRP
# 4  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL  READM_30_HIP_KNEE_HRRP
#
#   number_of_discharges excess_readmission_ratio predicted_readmission_rate  \
# 0                  798                   1.0072                    14.8575
# 1                  290                   1.1392                    14.0204
# 2                  569                   0.9913                    18.2153
# 3                 1061                   1.0135                    21.5968
# 4                  335                   1.0468                     5.0853
#
#   expected_readmission_rate number_of_readmissions  start_date    end_date  \
# 0                   14.7514                    119  07/01/2014  06/30/2017
# 1                   12.3077                     44  07/01/2014  06/30/2017
# 2                   18.3745                    103  07/01/2014  06/30/2017
# 3                   21.3101                    230  07/01/2014  06/30/2017
# 4                    4.8582                     18  07/01/2014  06/30/2017
#
#   footnote
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
with open('geninfo.pickle','rb') as read_file:
    geninfo_df = pickle.load(read_file)
    
geninfo_df.head(5)
# Out:
#   provider_id                      hospital_name                    address  \
# 0      260096         NORTH KANSAS CITY HOSPITAL    2800 CLAY EDWARDS DRIVE
# 1      450775    HCA HOUSTON HEALTHCARE KINGWOOD            22999 US HWY 59
# 2      200008              NORTHERN LIGHT HEALTH           144 STATE STREET
# 3      210018  MEDSTAR MONTGOMERY MEDICAL CENTER  18101 PRINCE PHILIP DRIVE
# 4      154056          EVANSVILLE STATE HOSPITAL        3400 LINCOLN AVENUE
#
#                 city state zip_code  county_name phone_number  \
# 0  NORTH KANSAS CITY    MO    64116         CLAY   8166912000
# 1           KINGWOOD    TX    77325       HARRIS   2813597500
# 2           PORTLAND    ME    04101   CUMBERLAND   2078793000
# 3              OLNEY    MD    20832   MONTGOMERY   3017748882
# 4         EVANSVILLE    IN    47714  VANDERBURGH   8124696800
#
#           hospital_type              hospital_ownership  ...  \
# 0  Acute Care Hospitals              Government - Local  ...
# 1  Acute Care Hospitals                     Proprietary  ...
# 2  Acute Care Hospitals   Voluntary non-profit - Church  ...
# 3  Acute Care Hospitals  Voluntary non-profit - Private  ...
# 4           Psychiatric              Government - State  ...
#
#    :@computed_region_csmy_5jwy meets_criteria_for_meaningful_use_of_ehrs  \
# 0                           18                                       NaN
# 1                          NaN                                      True
# 2                           49                                      True
# 3                           45                                       NaN
# 4                           35                                       NaN
#
#                     hospital_overall_rating_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#               mortality_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#          safety_of_care_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#             readmission_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#      patient_experience_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#   effectiveness_of_care_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#      timeliness_of_care_national_comparison_footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
#   efficient_use_of_medical_imaging_national_comparison_footnote
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Data are shown only for hospitals that partici...
#
# [5 rows x 36 columns]

# %%
with open('wageindex14.pickle','rb') as read_file:
    wageindex14_df = pickle.load(read_file)
    
wageindex14_df.head(5)
# Out:
#      CCN Case_Mix_Indexes FY_Wage_Index Avg_Hourly_Wage_FY2012  \
# 0  10001           1.7394        0.8106                27.3711
# 1  10005           1.3291         0.815                26.3289
# 2  10006            1.556        0.7436                  27.91
# 3  10007           1.0092        0.7094                23.2296
# 4  10008            0.947        0.7193                26.0069
#
#   Avg_Hourly_Wage_FY2013 Avg_Hourly_Wage_FY2014 3_Year_Avg_Hourly_Wage
# 0                28.0956                28.4305                27.9695
# 1                27.0526                28.3023                27.2443
# 2                27.9206                28.3321                28.0549
# 3                 22.959                22.6684                22.9586
# 4                26.2764                24.0769                25.4392

# %%
with open('wageindex15.pickle','rb') as read_file:
    wageindex15_df = pickle.load(read_file)
    
wageindex15_df.head(5)
# Out:
#      CCN Case_Mix_Indexes FY_Wage_Index Avg_Hourly_Wage_FY2013  \
# 0  10001           1.7647        0.7704                28.0956
# 1  10005           1.3589        0.8212                27.0526
# 2  10006           1.6742        0.7325                27.9206
# 3  10007           1.0283        0.6874                 22.959
# 4  10008           0.9257        0.6973                26.2764
#
#   Avg_Hourly_Wage_FY2014 Avg_Hourly_Wage_FY2015 3_Year_Avg_Hourly_Wage
# 0                28.4305                28.4012                  28.31
# 1                28.3023                27.7541                27.7003
# 2                28.3321                27.9861                28.0827
# 3                22.6684                22.1117                22.5769
# 4                24.0769                 23.713                24.6357

# %%
with open('wageindex16.pickle','rb') as read_file:
    wageindex16_df = pickle.load(read_file)
    
wageindex16_df.head(5)
# Out:
#       CCN  Case_Mix_Indexes  FY_Wage_Index  Avg_Hourly_Wage_FY2014  \
# 0  010001            1.6935         0.6941                 28.4305
# 1  010005            1.3210         0.8274                 28.3023
# 2  010006            1.6217         0.6875                 28.3321
# 3  010007            1.0092         0.6875                 22.6684
# 4  010008            0.9738         0.6974                 24.0769
#
#    Avg_Hourly_Wage_FY2015  Avg_Hourly_Wage_FY2016  3_Year_Avg_Hourly_Wage  \
# 0                 28.4012                 29.1656                 28.6629
# 1                 27.7541                 28.1275                 28.0762
# 2                 27.9861                 26.1226                 27.4785
# 3                 22.1117                 23.3987                 22.7179
# 4                 23.7130                 27.7051                 25.1787
#
#    Geographic_CBSA  Reclassified_Redesignated_CBSA Lugar_NECMA MGCRB_Reclass  \
# 0            20020                             NaN         NaN           NaN
# 1                1                         26620.0         NaN             Y
# 2            22520                             NaN         NaN           NaN
# 3                1                             NaN         NaN           NaN
# 4                1                             NaN         NaN           NaN
#
#   Hosp_Reclass  Out_Migration_Adj County_Name  County_Code
# 0          NaN                NaN     HOUSTON         1340
# 1          NaN             0.0263    MARSHALL         1470
# 2          NaN                NaN  LAUDERDALE         1380
# 3          NaN                NaN   COVINGTON         1190
# 4          NaN             0.0099    CRENSHAW         1200

# %%
with open('wageindex17.pickle','rb') as read_file:
    wageindex17_df = pickle.load(read_file)
    
wageindex17_df.head(5)
# Out:
#       CCN  Case_Mix_Indexes  FY_Wage_Index  Avg_Hourly_Wage_FY2015  \
# 0  010001            1.6667         0.7666                 28.4012
# 1  010005            1.3504         0.8099                 27.7541
# 2  010006            1.6484         0.6857                 27.9861
# 3  010007            1.0515         0.6857                 22.1117
# 4  010008            0.9257         0.6977                 23.7130
#
#    Avg_Hourly_Wage_FY2016  Avg_Hourly_Wage_FY2017  3_Year_Avg_Hourly_Wage  \
# 0                 29.1656                 29.5127                 29.0321
# 1                 28.1275                 28.4608                 28.1724
# 2                 26.1226                 27.5379                 27.2113
# 3                 23.3987                 25.2733                 23.5141
# 4                 27.7051                 25.2275                 25.5438
#
#    Geographic_CBSA  Reclassified_Redesignated_CBSA Lugar_NECMA MGCRB_Reclass  \
# 0            20020                         18880.0         NaN             Y
# 1                1                         26620.0         NaN             Y
# 2            22520                             NaN         NaN           NaN
# 3                1                             NaN         NaN           NaN
# 4                1                             NaN         NaN           NaN
#
#   Hosp_Reclass  Out_Migration_Adj County_Name  County_Code
# 0          NaN                NaN     HOUSTON       1340.0
# 1          NaN              0.053    MARSHALL       1470.0
# 2          NaN                NaN  LAUDERDALE       1380.0
# 3          NaN                NaN   COVINGTON       1190.0
# 4          NaN              0.012    CRENSHAW       1200.0

# %% [markdown]
# ### Census income data

# %%
with open('censusincome14.pickle','rb') as read_file:
    censusincome14_df = pickle.load(read_file)
    
censusincome14_df.head(5)
# Out:
#                id        Geographic Area Name  Households!!Estimate!!Total  \
# 0  0500000US04025     Yavapai County, Arizona                        90584
# 1  0500000US04027        Yuma County, Arizona                        70593
# 2  0500000US05007     Benton County, Arkansas                        86232
# 3  0500000US05031  Craighead County, Arkansas                        38548
# 4  0500000US05045   Faulkner County, Arkansas                        42782
#
#    Households!!Margin of Error!!Total  \
# 0                                2671
# 1                                1932
# 2                                1851
# 3                                1519
# 4                                1340
#
#    Households!!Estimate!!Less than $10,000  \
# 0                                      6.2
# 1                                      8.8
# 2                                      4.4
# 3                                     10.4
# 4                                      9.0
#
#    Households!!Margin of Error!!Less than $10,000  \
# 0                                             1.3
# 1                                             1.6
# 2                                             1.0
# 3                                             2.8
# 4                                             2.3
#
#    Households!!Estimate!!$10,000 to $14,999  \
# 0                                       7.3
# 1                                       6.6
# 2                                       5.2
# 3                                       6.6
# 4                                       4.4
#
#    Households!!Margin of Error!!$10,000 to $14,999  \
# 0                                              1.4
# 1                                              1.5
# 2                                              1.2
# 3                                              2.2
# 4                                              1.4
#
#    Households!!Estimate!!$15,000 to $24,999  \
# 0                                      12.4
# 1                                      16.0
# 2                                       9.5
# 3                                      13.4
# 4                                       9.5
#
#    Households!!Margin of Error!!$15,000 to $24,999  ...  \
# 0                                              1.9  ...
# 1                                              2.1  ...
# 2                                              1.4  ...
# 3                                              2.8  ...
# 4                                              2.0  ...
#
#    Nonfamily households!!Estimate!!Median income (dollars)  \
# 0                                              27972
# 1                                              24753
# 2                                              32835
# 3                                              22494
# 4                                              28823
#
#    Nonfamily households!!Margin of Error!!Median income (dollars)  \
# 0                                               2656
# 1                                               2868
# 2                                               2994
# 3                                               5780
# 4                                               3801
#
#    Nonfamily households!!Estimate!!Mean income (dollars)  \
# 0                                              38286
# 1                                              39274
# 2                                              43821
# 3                                              31622
# 4                                              39165
#
#    Nonfamily households!!Margin of Error!!Mean income (dollars)  \
# 0                                               3263
# 1                                               5702
# 2                                               4017
# 3                                               4698
# 4                                               6007
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# 0                                               37.3
# 1                                               34.6
# 2                                               24.7
# 3                                               22.2
# 4                                               26.1
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Nonfamily income in the past 12 months
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 130 columns]

# %%
with open('censusincome15.pickle','rb') as read_file:
    censusincome15_df = pickle.load(read_file)
    
censusincome15_df.head(5)
# Out:
#                id        Geographic Area Name  Households!!Estimate!!Total  \
# 0  0500000US12111   St. Lucie County, Florida                       108811
# 1  0500000US12113  Santa Rosa County, Florida                        60861
# 2  0500000US12115    Sarasota County, Florida                       177807
# 3  0500000US12117    Seminole County, Florida                       162739
# 4  0500000US12119      Sumter County, Florida                        51170
#
#    Households!!Margin of Error!!Total  \
# 0                                3814
# 1                                1910
# 2                                3612
# 3                                2735
# 4                                3126
#
#    Households!!Estimate!!Less than $10,000  \
# 0                                      8.8
# 1                                      5.0
# 2                                      4.3
# 3                                      5.8
# 4                                      7.3
#
#    Households!!Margin of Error!!Less than $10,000  \
# 0                                             1.9
# 1                                             1.7
# 2                                             0.8
# 3                                             1.2
# 4                                             2.6
#
#    Households!!Estimate!!$10,000 to $14,999  \
# 0                                       5.7
# 1                                       3.3
# 2                                       4.1
# 3                                       4.0
# 4                                       3.8
#
#    Households!!Margin of Error!!$10,000 to $14,999  \
# 0                                              1.3
# 1                                              1.4
# 2                                              0.8
# 3                                              0.9
# 4                                              1.6
#
#    Households!!Estimate!!$15,000 to $24,999  \
# 0                                      13.5
# 1                                      10.2
# 2                                      10.0
# 3                                      10.0
# 4                                       5.8
#
#    Households!!Margin of Error!!$15,000 to $24,999  ...  \
# 0                                              2.2  ...
# 1                                              2.3  ...
# 2                                              1.3  ...
# 3                                              1.5  ...
# 4                                              1.8  ...
#
#    Nonfamily households!!Estimate!!Median income (dollars)  \
# 0                                              29196
# 1                                              41322
# 2                                              36900
# 3                                              34113
# 4                                              31436
#
#    Nonfamily households!!Margin of Error!!Median income (dollars)  \
# 0                                               5116
# 1                                               7318
# 2                                               3103
# 3                                               3728
# 4                                               6375
#
#    Nonfamily households!!Estimate!!Mean income (dollars)  \
# 0                                              37699
# 1                                              51796
# 2                                              50121
# 3                                              44110
# 4                                              45466
#
#    Nonfamily households!!Margin of Error!!Mean income (dollars)  \
# 0                                               3478
# 1                                               6062
# 2                                               3557
# 3                                               3052
# 4                                               9104
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# 0                                               38.8
# 1                                               29.9
# 2                                               42.3
# 3                                               46.4
# 4                                               29.0
#
#    Nonfamily households!!Margin of Error!!PERCENT IMPUTED!!Nonfamily income in the past 12 months
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 130 columns]

# %%
with open('censusincome16.pickle','rb') as read_file:
    censusincome16_df = pickle.load(read_file)
    
censusincome16_df.head(5)
# Out:
#                id                Geographic Area Name  \
# 0  0500000US01131              Wilcox County, Alabama
# 1  0500000US01133             Winston County, Alabama
# 2  0500000US02013      Aleutians East Borough, Alaska
# 3  0500000US02016  Aleutians West Census Area, Alaska
# 4  0500000US02020      Anchorage Municipality, Alaska
#
#    Households!!Estimate!!Total  Households!!Margin of Error!!Total  \
# 0                         3792                                 200
# 1                         9436                                 332
# 2                          788                                 141
# 3                         1186                                 162
# 4                       104969                                 915
#
#    Households!!Estimate!!Less than $10,000  \
# 0                                     25.6
# 1                                     10.0
# 2                                      3.4
# 3                                      2.5
# 4                                      2.8
#
#    Households!!Margin of Error!!Less than $10,000  \
# 0                                             3.9
# 1                                             1.6
# 2                                             1.2
# 3                                             0.8
# 4                                             0.4
#
#    Households!!Estimate!!$10,000 to $14,999  \
# 0                                       8.7
# 1                                       9.8
# 2                                       4.6
# 3                                       2.9
# 4                                       2.7
#
#    Households!!Margin of Error!!$10,000 to $14,999  \
# 0                                              2.1
# 1                                              1.8
# 2                                              1.6
# 3                                              0.8
# 4                                              0.4
#
#    Households!!Estimate!!$15,000 to $24,999  \
# 0                                      16.4
# 1                                      19.0
# 2                                      10.3
# 3                                       4.1
# 4                                       5.9
#
#    Households!!Margin of Error!!$15,000 to $24,999  ...  \
# 0                                              3.7  ...
# 1                                              2.4  ...
# 2                                              1.9  ...
# 3                                              1.3  ...
# 4                                              0.5  ...
#
#    Nonfamily households!!Estimate!!Median income (dollars)  \
# 0                                              13225
# 1                                              18593
# 2                                              49250
# 3                                              69583
# 4                                              53517
#
#    Nonfamily households!!Margin of Error!!Median income (dollars)  \
# 0                                               2739
# 1                                                840
# 2                                               5537
# 3                                              14650
# 4                                               1775
#
#    Nonfamily households!!Estimate!!Mean income (dollars)  \
# 0                                              18193
# 1                                              26769
# 2                                              57257
# 3                                              83256
# 4                                              71924
#
#    Nonfamily households!!Margin of Error!!Mean income (dollars)  \
# 0                                               2518
# 1                                               2235
# 2                                               4937
# 3                                               6610
# 4                                               3133
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                               49.4
# 1                                               35.0
# 2                                               15.2
# 3                                               22.5
# 4                                               21.4
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 130 columns]

# %%
with open('censusincome17.pickle','rb') as read_file:
    censusincome17_df = pickle.load(read_file)
    
censusincome17_df.head(5)
# Out:
#                id             Geographic Area Name  \
# 0  0500000US25003  Berkshire County, Massachusetts
# 1  0500000US25005    Bristol County, Massachusetts
# 2  0500000US25009      Essex County, Massachusetts
# 3  0500000US25011   Franklin County, Massachusetts
# 4  0500000US25013    Hampden County, Massachusetts
#
#    Households!!Estimate!!Total  Households!!Margin of Error!!Total  \
# 0                        54193                                1636
# 1                       218570                                2828
# 2                       294092                                2740
# 3                        29239                                 952
# 4                       180933                                1783
#
#    Households!!Estimate!!Less than $10,000  \
# 0                                      5.1
# 1                                      5.1
# 2                                      5.6
# 3                                      5.0
# 4                                      8.1
#
#    Households!!Margin of Error!!Less than $10,000  \
# 0                                             1.6
# 1                                             0.8
# 2                                             0.8
# 3                                             1.9
# 4                                             1.1
#
#    Households!!Estimate!!$10,000 to $14,999  \
# 0                                       5.2
# 1                                       5.6
# 2                                       4.2
# 3                                       5.8
# 4                                       7.2
#
#    Households!!Margin of Error!!$10,000 to $14,999  \
# 0                                              1.7
# 1                                              0.7
# 2                                              0.6
# 3                                              1.9
# 4                                              1.0
#
#    Households!!Estimate!!$15,000 to $24,999  \
# 0                                       9.8
# 1                                       9.6
# 2                                       7.7
# 3                                       8.7
# 4                                      10.4
#
#    Households!!Margin of Error!!$15,000 to $24,999  ...  \
# 0                                              1.8  ...
# 1                                              1.1  ...
# 2                                              0.9  ...
# 3                                              2.1  ...
# 4                                              1.1  ...
#
#    Nonfamily households!!Estimate!!Median income (dollars)  \
# 0                                              34516
# 1                                              36020
# 2                                              40020
# 3                                              39891
# 4                                              32079
#
#    Nonfamily households!!Margin of Error!!Median income (dollars)  \
# 0                                               4856
# 1                                               3053
# 2                                               3255
# 3                                               4226
# 4                                               2697
#
#    Nonfamily households!!Estimate!!Mean income (dollars)  \
# 0                                              47856
# 1                                              55694
# 2                                              58703
# 3                                              47114
# 4                                              43047
#
#    Nonfamily households!!Margin of Error!!Mean income (dollars)  \
# 0                                               5167
# 1                                               3873
# 2                                               3867
# 3                                               4338
# 4                                               2879
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Nonfamily households!!Estimate!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                               39.9
# 1                                               45.9
# 2                                               37.9
# 3                                               30.0
# 4                                               32.1
#
#    Nonfamily households!!Margin of Error!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 130 columns]

# %% [markdown]
# ### Education

# %%
with open('education.pickle','rb') as read_file:
    education_df = pickle.load(read_file)
    
education_df.head(5)
# Out:
#    FIPS Code State       Area name  2003 Rural-urban Continuum Code  \
# 0        0.0    US   United States                              NaN
# 1     1000.0    AL         Alabama                              NaN
# 2     1001.0    AL  Autauga County                              2.0
# 3     1003.0    AL  Baldwin County                              4.0
# 4     1005.0    AL  Barbour County                              6.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    2013 Urban Influence Code Less than a high school diploma, 1970  \
# 0                        NaN                            52,373,312
# 1                        NaN                             1,062,306
# 2                        2.0                                 6,611
# 3                        2.0                                18,726
# 4                        6.0                                 8,120
#
#   High school diploma only, 1970 Some college (1-3 years), 1970  ...  \
# 0                     34,158,051                     11,650,730  ...
# 1                        468,269                        136,287  ...
# 2                          3,757                            933  ...
# 3                          8,426                          2,334  ...
# 4                          2,242                            581  ...
#
#   Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                               24.4
# 1                                               19.0
# 2                                               18.0
# 3                                               23.1
# 4                                               10.9
#
#    Less than a high school diploma, 2013-17  \
# 0                                27,437,114
# 1                                   481,059
# 2                                     4,521
# 3                                    13,997
# 4                                     4,960
#
#    High school diploma only, 2013-17  \
# 0                         59,093,612
# 1                          1,012,551
# 2                             12,363
# 3                             39,771
# 4                              6,549
#
#    Some college or associate's degree, 2013-17  \
# 0                                   62,853,315
# 1                                      979,449
# 2                                       10,697
# 3                                       45,286
# 4                                        4,707
#
#    Bachelor's degree or higher, 2013-17  \
# 0                            66,887,603
# 1                               803,578
# 2                                 9,176
# 3                                43,968
# 4                                 2,218
#
#   Percent of adults with less than a high school diploma, 2013-17  \
# 0                                               12.7
# 1                                               14.7
# 2                                               12.3
# 3                                                9.8
# 4                                               26.9
#
#   Percent of adults with a high school diploma only, 2013-17  \
# 0                                               27.3
# 1                                               30.9
# 2                                               33.6
# 3                                               27.8
# 4                                               35.5
#
#   Percent of adults completing some college or associate's degree, 2013-17  \
# 0                                               29.1
# 1                                               29.9
# 2                                               29.1
# 3                                               31.7
# 4                                               25.5
#
#   Percent of adults with a bachelor's degree or higher, 2013-17  Unnamed: 47
# 0                                               30.9                     NaN
# 1                                               24.5                     NaN
# 2                                               25.0                     NaN
# 3                                               30.7                     NaN
# 4                                               12.0                     NaN
#
# [5 rows x 48 columns]

# %%
# !ls
# Out:
# CMS 1655-P FY 2017 Proposed Rule Table 2.txt
# CMS 1655-P FY 2017 Proposed Rule Table 2_2.txt
# Education.csv
# __pycache__
# census_income_data.csv
# census_income_data_14.csv
# census_income_data_15.csv
# census_income_data_16.csv
# census_income_data_17.csv
# censusincome.pickle
# censusincome14.pickle
# censusincome15.pickle
# censusincome16.pickle
# censusincome17.pickle
# education.pickle
# geninfo.pickle
# hosp.pickle
# hrrp.pickle
# importing data + EDA.ipynb
# modeling.ipynb
# us_state_abbrev.py
# wage_index_14.txt
# wage_index_14_2.txt
# wage_index_15.csv
# wage_index_15.txt
# wage_index_15_2.csv
# wage_index_16.txt
# wage_index_17.txt
# wageindex.pickle
# wageindex14.pickle
# wageindex15.pickle
# wageindex16.pickle
# wageindex17.pickle
# web scraping.ipynb

# %% [markdown]
# ## Check/clean data

# %% [markdown]
# ### General Info

# %%
geninfo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5334 entries, 0 to 5333
# Data columns (total 36 columns):
# provider_id                                                      5334 non-null object
# hospital_name                                                    5334 non-null object
# address                                                          5334 non-null object
# city                                                             5334 non-null object
# state                                                            5334 non-null object
# zip_code                                                         5334 non-null object
# county_name                                                      5334 non-null object
# phone_number                                                     5334 non-null object
# hospital_type                                                    5334 non-null object
# hospital_ownership                                               5334 non-null object
# emergency_services                                               5334 non-null bool
# hospital_overall_rating                                          5334 non-null object
# mortality_national_comparison                                    5334 non-null object
# safety_of_care_national_comparison                               5334 non-null object
# readmission_national_comparison                                  5334 non-null object
# patient_experience_national_comparison                           5334 non-null object
# effectiveness_of_care_national_comparison                        5334 non-null object
# timeliness_of_care_national_comparison                           5334 non-null object
# efficient_use_of_medical_imaging_national_comparison             5334 non-null object
# location_city                                                    5334 non-null object
# location                                                         4933 non-null object
# location_address                                                 5334 non-null object
# location_zip                                                     5334 non-null object
# location_state                                                   5334 non-null object
# :@computed_region_f3tr_pr43                                      4930 non-null object
# :@computed_region_nwen_78xc                                      4930 non-null object
# :@computed_region_csmy_5jwy                                      4879 non-null object
# meets_criteria_for_meaningful_use_of_ehrs                        3710 non-null object
# hospital_overall_rating_footnote                                 1753 non-null object
# mortality_national_comparison_footnote                           1951 non-null object
# safety_of_care_national_comparison_footnote                      2711 non-null object
# readmission_national_comparison_footnote                         1477 non-null object
# patient_experience_national_comparison_footnote                  1911 non-null object
# effectiveness_of_care_national_comparison_footnote               1514 non-null object
# timeliness_of_care_national_comparison_footnote                  1587 non-null object
# efficient_use_of_medical_imaging_national_comparison_footnote    2292 non-null object
# dtypes: bool(1), object(35)
# memory usage: 1.4+ MB

# %%
geninfo_df["location_zip"].unique()
# Out:
# array(['64116', '77325', '04101', ..., '58341', '18301', '13901'],
#       dtype=object)

# %%
geninfo = geninfo_df.loc[:,['provider_id','hospital_name','state','zip_code','county_name','hospital_type',
                     'hospital_ownership','emergency_services','hospital_overall_rating',
                     'mortality_national_comparison','safety_of_care_national_comparison',
                     'patient_experience_national_comparison','effectiveness_of_care_national_comparison',
                     'timeliness_of_care_national_comparison','efficient_use_of_medical_imaging_national_comparison']]
geninfo['county_st'] = geninfo['county_name']+"_"+geninfo['state']
geninfo.head(5)
# Out:
#   provider_id                      hospital_name state zip_code  county_name  \
# 0      260096         NORTH KANSAS CITY HOSPITAL    MO    64116         CLAY
# 1      450775    HCA HOUSTON HEALTHCARE KINGWOOD    TX    77325       HARRIS
# 2      200008              NORTHERN LIGHT HEALTH    ME    04101   CUMBERLAND
# 3      210018  MEDSTAR MONTGOMERY MEDICAL CENTER    MD    20832   MONTGOMERY
# 4      154056          EVANSVILLE STATE HOSPITAL    IN    47714  VANDERBURGH
#
#           hospital_type              hospital_ownership  emergency_services  \
# 0  Acute Care Hospitals              Government - Local                True
# 1  Acute Care Hospitals                     Proprietary                True
# 2  Acute Care Hospitals   Voluntary non-profit - Church                True
# 3  Acute Care Hospitals  Voluntary non-profit - Private                True
# 4           Psychiatric              Government - State               False
#
#   hospital_overall_rating mortality_national_comparison  \
# 0                       3  Same as the national average
# 1                       3    Above the national average
# 2                       5  Same as the national average
# 3                       3  Same as the national average
# 4           Not Available                 Not Available
#
#   safety_of_care_national_comparison patient_experience_national_comparison  \
# 0         Above the national average             Above the national average
# 1         Above the national average             Below the national average
# 2         Below the national average             Above the national average
# 3         Below the national average             Below the national average
# 4                      Not Available                          Not Available
#
#   effectiveness_of_care_national_comparison  \
# 0              Same as the national average
# 1              Same as the national average
# 2              Same as the national average
# 3              Same as the national average
# 4                             Not Available
#
#   timeliness_of_care_national_comparison  \
# 0             Above the national average
# 1           Same as the national average
# 2           Same as the national average
# 3             Below the national average
# 4                          Not Available
#
#   efficient_use_of_medical_imaging_national_comparison       county_st
# 0                         Below the national average           CLAY_MO
# 1                       Same as the national average         HARRIS_TX
# 2                       Same as the national average     CUMBERLAND_ME
# 3                         Above the national average     MONTGOMERY_MD
# 4                                      Not Available    VANDERBURGH_IN

# %%
geninfo['hospital_ownership'].value_counts()
# Out:
# Voluntary non-profit - Private                 2191
# Proprietary                                    1067
# Government - Hospital District or Authority     541
# Voluntary non-profit - Other                    434
# Government - Local                              431
# Voluntary non-profit - Church                   331
# Government - State                              209
# Physician                                        70
# Government - Federal                             51
# Tribal                                            9
# Name: hospital_ownership, dtype: int64

# %%
geninfo['hospital_type'].value_counts()
# Out:
# Acute Care Hospitals         3310
# Critical Access Hospitals    1351
# Psychiatric                   576
# Childrens                      97
# Name: hospital_type, dtype: int64

# %%
geninfo['emergency_services'].value_counts()
# Out:
# True     4486
# False     848
# Name: emergency_services, dtype: int64

# %%
geninfo['hospital_overall_rating'].value_counts()
# Out:
# Not Available    1631
# 3                1254
# 4                1085
# 2                 792
# 5                 291
# 1                 281
# Name: hospital_overall_rating, dtype: int64

# %% [markdown]
# ### Hospital Readmissions info

# %%
hrrp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19674 entries, 0 to 19673
# Data columns (total 12 columns):
# hospital_name                 19674 non-null object
# provider_id                   19674 non-null object
# state                         19674 non-null object
# measure_name                  19674 non-null object
# number_of_discharges          19674 non-null object
# excess_readmission_ratio      19674 non-null object
# predicted_readmission_rate    19674 non-null object
# expected_readmission_rate     19674 non-null object
# number_of_readmissions        19674 non-null object
# start_date                    19674 non-null object
# end_date                      19674 non-null object
# footnote                      8157 non-null object
# dtypes: object(12)
# memory usage: 1.8+ MB

# %%
hrrp_df['measure_name'].value_counts()
# Out:
# READM_30_PN_HRRP          3279
# READM_30_HF_HRRP          3279
# READM_30_CABG_HRRP        3279
# READM_30_HIP_KNEE_HRRP    3279
# READM_30_COPD_HRRP        3279
# READM_30_AMI_HRRP         3279
# Name: measure_name, dtype: int64

# %%
hrrp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19674 entries, 0 to 19673
# Data columns (total 12 columns):
# hospital_name                 19674 non-null object
# provider_id                   19674 non-null object
# state                         19674 non-null object
# measure_name                  19674 non-null object
# number_of_discharges          19674 non-null object
# excess_readmission_ratio      19674 non-null object
# predicted_readmission_rate    19674 non-null object
# expected_readmission_rate     19674 non-null object
# number_of_readmissions        19674 non-null object
# start_date                    19674 non-null object
# end_date                      19674 non-null object
# footnote                      8157 non-null object
# dtypes: object(12)
# memory usage: 1.8+ MB

# %%
# Clean data:
# convert numeric columns to numeric format
num_cols = ['number_of_discharges','excess_readmission_ratio','predicted_readmission_rate',
            'expected_readmission_rate','number_of_readmissions']
for col in num_cols:
    hrrp_df[col].replace('Not Available',np.NaN, inplace=True)
    hrrp_df[col] = hrrp_df[col].astype(float, inplace=True)
    
# convert dates into date format
# hrrp_df['start_date']= [dt.datetime.strptime(x, '%m/%d/%Y') for x in hrrp_df['start_date']]
# hrrp_df['end_date']= [dt.datetime.strptime(x, '%m/%d/%Y') for x in hrrp_df['end_date']]
hrrp_df["readmitrate_calc"] = (hrrp_df['number_of_readmissions']/hrrp_df['number_of_discharges'])*100
hrrp_df["readmitrate_ratio"] = hrrp_df["readmitrate_calc"]/hrrp_df["predicted_readmission_rate"]

hrrp_df.info()
hrrp_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19674 entries, 0 to 19673
# Data columns (total 14 columns):
# hospital_name                 19674 non-null object
# provider_id                   19674 non-null object
# state                         19674 non-null object
# measure_name                  19674 non-null object
# number_of_discharges          11655 non-null float64
# excess_readmission_ratio      14280 non-null float64
# predicted_readmission_rate    14280 non-null float64
# expected_readmission_rate     14280 non-null float64
# number_of_readmissions        11532 non-null float64
# start_date                    19674 non-null object
# end_date                      19674 non-null object
# footnote                      8157 non-null object
# readmitrate_calc              11532 non-null float64
# readmitrate_ratio             11532 non-null float64
# dtypes: float64(7), object(7)
# memory usage: 2.1+ MB
#                       hospital_name provider_id state            measure_name  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL       READM_30_AMI_HRRP
# 1  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL      READM_30_CABG_HRRP
# 2  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL      READM_30_COPD_HRRP
# 3  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL        READM_30_HF_HRRP
# 4  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL  READM_30_HIP_KNEE_HRRP
#
#    number_of_discharges  excess_readmission_ratio  predicted_readmission_rate  \
# 0                 798.0                    1.0072                     14.8575
# 1                 290.0                    1.1392                     14.0204
# 2                 569.0                    0.9913                     18.2153
# 3                1061.0                    1.0135                     21.5968
# 4                 335.0                    1.0468                      5.0853
#
#    expected_readmission_rate  number_of_readmissions  start_date    end_date  \
# 0                    14.7514                   119.0  07/01/2014  06/30/2017
# 1                    12.3077                    44.0  07/01/2014  06/30/2017
# 2                    18.3745                   103.0  07/01/2014  06/30/2017
# 3                    21.3101                   230.0  07/01/2014  06/30/2017
# 4                     4.8582                    18.0  07/01/2014  06/30/2017
#
#   footnote  readmitrate_calc  readmitrate_ratio
# 0      NaN         14.912281           1.003687
# 1      NaN         15.172414           1.082167
# 2      NaN         18.101933           0.993776
# 3      NaN         21.677663           1.003744
# 4      NaN          5.373134           1.056601

# %%
plt.hist(hrrp_df['excess_readmission_ratio'],bins=20);
# Out:
# /Users/Jocelyn/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/Jocelyn/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# measures = ['READM_30_AMI_HRRP','READM_30_CABG_HRRP','READM_30_COPD_HRRP','READM_30_HF_HRRP','READM_30_HIP_KNEE_HRRP']
# names = ['hrrp_a','hrrp_b','hrrp_c','hrrp_d','hrrp_e']

# for measure in measures:
#     for name in names.items():
#         name = hrrp_df.loc[hrrp_df['measure_name'] == measure]

hrrp_a = hrrp_df.loc[hrrp_df['measure_name'] == 'READM_30_AMI_HRRP']
hrrp_b = hrrp_df.loc[hrrp_df['measure_name'] == 'READM_30_CABG_HRRP']
hrrp_c = hrrp_df.loc[hrrp_df['measure_name'] == 'READM_30_COPD_HRRP']
hrrp_d = hrrp_df.loc[hrrp_df['measure_name'] == 'READM_30_HF_HRRP']
hrrp_e = hrrp_df.loc[hrrp_df['measure_name'] == 'READM_30_HIP_KNEE_HRRP']

plt.figure(figsize=(15,8))
plt.scatter(hrrp_a['number_of_discharges'],hrrp_a['predicted_readmission_rate'],alpha=0.2,color='r');
plt.scatter(hrrp_b['number_of_discharges'],hrrp_b['predicted_readmission_rate'],alpha=0.2,color='g');
plt.scatter(hrrp_c['number_of_discharges'],hrrp_c['predicted_readmission_rate'],alpha=0.2,color='y');
plt.scatter(hrrp_d['number_of_discharges'],hrrp_d['predicted_readmission_rate'],alpha=0.2,color='c');
plt.scatter(hrrp_e['number_of_discharges'],hrrp_e['predicted_readmission_rate'],alpha=0.2,color='m');

# %%
plt.scatter(hrrp_df['predicted_readmission_rate'],hrrp_df['excess_readmission_ratio'],alpha=0.1);

# %%
hrrp_1 = hrrp_df.groupby(['provider_id']).count().sort_values(by='excess_readmission_ratio')
hrrp_1.loc[hrrp_1['excess_readmission_ratio'] == 6]
# Out:
#              hospital_name  state  measure_name  number_of_discharges  \
# provider_id
# 450271                   6      6             6                     4
# 050232                   6      6             6                     5
# 450042                   6      6             6                     6
# 450231                   6      6             6                     6
# 450743                   6      6             6                     5
# 220002                   6      6             6                     5
# 450040                   6      6             6                     6
# 230038                   6      6             6                     6
# 050107                   6      6             6                     5
# 450723                   6      6             6                     4
# 450358                   6      6             6                     6
# 450718                   6      6             6                     5
# 050093                   6      6             6                     6
# 230046                   6      6             6                     6
# 450324                   6      6             6                     6
# 140280                   6      6             6                     6
# 450035                   6      6             6                     2
# 050226                   6      6             6                     4
# 450229                   6      6             6                     5
# 050242                   6      6             6                     5
# 450222                   6      6             6                     4
# 450844                   6      6             6                     5
# 450054                   6      6             6                     6
# 450713                   6      6             6                     6
# 140281                   6      6             6                     6
# 450711                   6      6             6                     4
# 450403                   6      6             6                     5
# 140276                   6      6             6                     6
# 050099                   6      6             6                     4
# 450068                   6      6             6                     6
# ...                    ...    ...           ...                   ...
# 140054                   6      6             6                     5
# 390127                   6      6             6                     5
# 390142                   6      6             6                     4
# 250078                   6      6             6                     6
# 060031                   6      6             6                     6
# 060032                   6      6             6                     5
# 060034                   6      6             6                     5
# 390115                   6      6             6                     6
# 140046                   6      6             6                     6
# 390110                   6      6             6                     5
# 140053                   6      6             6                     6
# 260078                   6      6             6                     4
# 390145                   6      6             6                     5
# 060024                   6      6             6                     5
# 060015                   6      6             6                     4
# 140067                   6      6             6                     6
# 250048                   6      6             6                     6
# 060020                   6      6             6                     5
# 390180                   6      6             6                     4
# 390179                   6      6             6                     6
# 060027                   6      6             6                     4
# 390174                   6      6             6                     6
# 390164                   6      6             6                     6
# 390162                   6      6             6                     6
# 060022                   6      6             6                     6
# 060023                   6      6             6                     4
# 390153                   6      6             6                     5
# 140062                   6      6             6                     6
# 390168                   6      6             6                     4
# 010001                   6      6             6                     6
#
#              excess_readmission_ratio  predicted_readmission_rate  \
# provider_id
# 450271                              6                           6
# 050232                              6                           6
# 450042                              6                           6
# 450231                              6                           6
# 450743                              6                           6
# 220002                              6                           6
# 450040                              6                           6
# 230038                              6                           6
# 050107                              6                           6
# 450723                              6                           6
# 450358                              6                           6
# 450718                              6                           6
# 050093                              6                           6
# 230046                              6                           6
# 450324                              6                           6
# 140280                              6                           6
# 450035                              6                           6
# 050226                              6                           6
# 450229                              6                           6
# 050242                              6                           6
# 450222                              6                           6
# 450844                              6                           6
# 450054                              6                           6
# 450713                              6                           6
# 140281                              6                           6
# 450711                              6                           6
# 450403                              6                           6
# 140276                              6                           6
# 050099                              6                           6
# 450068                              6                           6
# ...                               ...                         ...
# 140054                              6                           6
# 390127                              6                           6
# 390142                              6                           6
# 250078                              6                           6
# 060031                              6                           6
# 060032                              6                           6
# 060034                              6                           6
# 390115                              6                           6
# 140046                              6                           6
# 390110                              6                           6
# 140053                              6                           6
# 260078                              6                           6
# 390145                              6                           6
# 060024                              6                           6
# 060015                              6                           6
# 140067                              6                           6
# 250048                              6                           6
# 060020                              6                           6
# 390180                              6                           6
# 390179                              6                           6
# 060027                              6                           6
# 390174                              6                           6
# 390164                              6                           6
# 390162                              6                           6
# 060022                              6                           6
# 060023                              6                           6
# 390153                              6                           6
# 140062                              6                           6
# 390168                              6                           6
# 010001                              6                           6
#
#              expected_readmission_rate  number_of_readmissions  start_date  \
# provider_id
# 450271                               6                       4           6
# 050232                               6                       5           6
# 450042                               6                       6           6
# 450231                               6                       6           6
# 450743                               6                       5           6
# 220002                               6                       5           6
# 450040                               6                       6           6
# 230038                               6                       6           6
# 050107                               6                       5           6
# 450723                               6                       4           6
# 450358                               6                       6           6
# 450718                               6                       5           6
# 050093                               6                       6           6
# 230046                               6                       6           6
# 450324                               6                       6           6
# 140280                               6                       6           6
# 450035                               6                       2           6
# 050226                               6                       4           6
# 450229                               6                       5           6
# 050242                               6                       5           6
# 450222                               6                       4           6
# 450844                               6                       5           6
# 450054                               6                       6           6
# 450713                               6                       6           6
# 140281                               6                       6           6
# 450711                               6                       4           6
# 450403                               6                       5           6
# 140276                               6                       6           6
# 050099                               6                       4           6
# 450068                               6                       6           6
# ...                                ...                     ...         ...
# 140054                               6                       5           6
# 390127                               6                       5           6
# 390142                               6                       4           6
# 250078                               6                       6           6
# 060031                               6                       6           6
# 060032                               6                       5           6
# 060034                               6                       5           6
# 390115                               6                       6           6
# 140046                               6                       6           6
# 390110                               6                       5           6
# 140053                               6                       6           6
# 260078                               6                       4           6
# 390145                               6                       5           6
# 060024                               6                       5           6
# 060015                               6                       4           6
# 140067                               6                       6           6
# 250048                               6                       6           6
# 060020                               6                       5           6
# 390180                               6                       4           6
# 390179                               6                       6           6
# 060027                               6                       4           6
# 390174                               6                       6           6
# 390164                               6                       6           6
# 390162                               6                       6           6
# 060022                               6                       6           6
# 060023                               6                       4           6
# 390153                               6                       5           6
# 140062                               6                       6           6
# 390168                               6                       4           6
# 010001                               6                       6           6
#
#              end_date  footnote  readmitrate_calc  readmitrate_ratio
# provider_id
# 450271              6         2                 4                  4
# 050232              6         1                 5                  5
# 450042              6         0                 6                  6
# 450231              6         0                 6                  6
# 450743              6         1                 5                  5
# 220002              6         1                 5                  5
# 450040              6         0                 6                  6
# 230038              6         0                 6                  6
# 050107              6         1                 5                  5
# 450723              6         2                 4                  4
# 450358              6         0                 6                  6
# 450718              6         1                 5                  5
# 050093              6         0                 6                  6
# 230046              6         0                 6                  6
# 450324              6         0                 6                  6
# 140280              6         0                 6                  6
# 450035              6         4                 2                  2
# 050226              6         2                 4                  4
# 450229              6         1                 5                  5
# 050242              6         1                 5                  5
# 450222              6         2                 4                  4
# 450844              6         1                 5                  5
# 450054              6         0                 6                  6
# 450713              6         0                 6                  6
# 140281              6         0                 6                  6
# 450711              6         2                 4                  4
# 450403              6         1                 5                  5
# 140276              6         0                 6                  6
# 050099              6         2                 4                  4
# 450068              6         0                 6                  6
# ...               ...       ...               ...                ...
# 140054              6         1                 5                  5
# 390127              6         1                 5                  5
# 390142              6         2                 4                  4
# 250078              6         0                 6                  6
# 060031              6         0                 6                  6
# 060032              6         1                 5                  5
# 060034              6         1                 5                  5
# 390115              6         0                 6                  6
# 140046              6         0                 6                  6
# 390110              6         1                 5                  5
# 140053              6         0                 6                  6
# 260078              6         2                 4                  4
# 390145              6         1                 5                  5
# 060024              6         1                 5                  5
# 060015              6         2                 4                  4
# 140067              6         0                 6                  6
# 250048              6         0                 6                  6
# 060020              6         1                 5                  5
# 390180              6         2                 4                  4
# 390179              6         0                 6                  6
# 060027              6         2                 4                  4
# 390174              6         0                 6                  6
# 390164              6         0                 6                  6
# 390162              6         0                 6                  6
# 060022              6         0                 6                  6
# 060023              6         2                 4                  4
# 390153              6         1                 5                  5
# 140062              6         0                 6                  6
# 390168              6         2                 4                  4
# 010001              6         0                 6                  6
#
# [968 rows x 13 columns]

# %%
plt.hist(hrrp_1['excess_readmission_ratio'],bins=7);

# %%
hrrp_df.loc[hrrp_df['provider_id']=='390168']
# Out:
#                   hospital_name provider_id state            measure_name  \
# 14850  BUTLER MEMORIAL HOSPITAL      390168    PA       READM_30_AMI_HRRP
# 14851  BUTLER MEMORIAL HOSPITAL      390168    PA      READM_30_CABG_HRRP
# 14852  BUTLER MEMORIAL HOSPITAL      390168    PA      READM_30_COPD_HRRP
# 14853  BUTLER MEMORIAL HOSPITAL      390168    PA        READM_30_HF_HRRP
# 14854  BUTLER MEMORIAL HOSPITAL      390168    PA  READM_30_HIP_KNEE_HRRP
# 14855  BUTLER MEMORIAL HOSPITAL      390168    PA        READM_30_PN_HRRP
#
#        number_of_discharges  excess_readmission_ratio  \
# 14850                 188.0                    0.9612
# 14851                   NaN                    0.8876
# 14852                 215.0                    0.9566
# 14853                 268.0                    0.8478
# 14854                   NaN                    0.7768
# 14855                 300.0                    0.8262
#
#        predicted_readmission_rate  expected_readmission_rate  \
# 14850                     15.1245                    15.7355
# 14851                     12.4451                    14.0207
# 14852                     17.3279                    18.1148
# 14853                     16.8601                    19.8879
# 14854                      3.1733                     4.0852
# 14855                     14.4433                    17.4809
#
#        number_of_readmissions  start_date    end_date  \
# 14850                    26.0  07/01/2014  06/30/2017
# 14851                     NaN  07/01/2014  06/30/2017
# 14852                    34.0  07/01/2014  06/30/2017
# 14853                    35.0  07/01/2014  06/30/2017
# 14854                     NaN  07/01/2014  06/30/2017
# 14855                    32.0  07/01/2014  06/30/2017
#
#                                                 footnote  readmitrate_calc  \
# 14850                                                NaN         13.829787
# 14851  5 - Results are not available for this reporti...               NaN
# 14852                                                NaN         15.813953
# 14853                                                NaN         13.059701
# 14854  5 - Results are not available for this reporti...               NaN
# 14855                                                NaN         10.666667
#
#        readmitrate_ratio
# 14850           0.914396
# 14851                NaN
# 14852           0.912630
# 14853           0.774592
# 14854                NaN
# 14855           0.738520

# %%
check = hrrp_df.loc[(hrrp_df['number_of_discharges'].isna()) & (hrrp_df['excess_readmission_ratio'].isna() == False)]

# %%
check['measure_name'].value_counts()
# Out:
# READM_30_HIP_KNEE_HRRP    1184
# READM_30_AMI_HRRP          421
# READM_30_CABG_HRRP         413
# READM_30_COPD_HRRP         318
# READM_30_HF_HRRP           212
# READM_30_PN_HRRP           200
# Name: measure_name, dtype: int64

# %%
check2 = hrrp_df.loc[(hrrp_df['number_of_discharges'].isna())]
check2['measure_name'].value_counts()
# Out:
# READM_30_CABG_HRRP        2672
# READM_30_HIP_KNEE_HRRP    1940
# READM_30_AMI_HRRP         1567
# READM_30_COPD_HRRP         719
# READM_30_HF_HRRP           602
# READM_30_PN_HRRP           519
# Name: measure_name, dtype: int64

# %%
check3 = hrrp_df.loc[(hrrp_df['number_of_discharges'].isna()==False) & (hrrp_df['predicted_readmission_rate'].isna() == False)]
check3['measure_name'].value_counts()
# Out:
# READM_30_PN_HRRP          2748
# READM_30_HF_HRRP          2670
# READM_30_COPD_HRRP        2551
# READM_30_AMI_HRRP         1666
# READM_30_HIP_KNEE_HRRP    1301
# READM_30_CABG_HRRP         596
# Name: measure_name, dtype: int64

# %%
hrrp_2 = hrrp_df.dropna(subset = ['number_of_discharges','excess_readmission_ratio',
                                  'predicted_readmission_rate','expected_readmission_rate',
                                  'number_of_readmissions'])

# %%
hrrp_2.shape
# Out:
# (11532, 14)

# %%
hrrp_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11532 entries, 0 to 19595
# Data columns (total 14 columns):
# hospital_name                 11532 non-null object
# provider_id                   11532 non-null object
# state                         11532 non-null object
# measure_name                  11532 non-null object
# number_of_discharges          11532 non-null float64
# excess_readmission_ratio      11532 non-null float64
# predicted_readmission_rate    11532 non-null float64
# expected_readmission_rate     11532 non-null float64
# number_of_readmissions        11532 non-null float64
# start_date                    11532 non-null object
# end_date                      11532 non-null object
# footnote                      15 non-null object
# readmitrate_calc              11532 non-null float64
# readmitrate_ratio             11532 non-null float64
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %%
# TEST - just use hip/knee

hrrp_2 = hrrp_2.loc[hrrp_df['measure_name'] == 'READM_30_HIP_KNEE_HRRP']

#group to get weighted average rates weighted by # of readmissions

#weighted excess readmission ratio
def my_agg(x):
    names = {'weighted_avg_EXCESS': (x['excess_readmission_ratio'] * x['number_of_discharges']).sum()/x['number_of_discharges'].sum()}
    return pd.Series(names, index=['weighted_avg_EXCESS'])

#weighted predicted readmit rate
def my_agg_p(x):
    names = {'weighted_avg_PRR': (x['predicted_readmission_rate'] * x['number_of_discharges']).sum()/x['number_of_discharges'].sum()}
    return pd.Series(names, index=['weighted_avg_PRR'])

#weighted expected readmit rate
def my_agg_e(x):
    names = {'weighted_avg_ERR': (x['expected_readmission_rate'] * x['number_of_discharges']).sum()/x['number_of_discharges'].sum()}
    return pd.Series(names, index=['weighted_avg_ERR'])

#apply calcs individually and merge
hrrp_2_1 = hrrp_2.groupby(['provider_id'])[['number_of_discharges','number_of_readmissions']].sum()
hrrp_2_1['raw_avg_readmitrate'] = hrrp_2_1['number_of_readmissions']/hrrp_2_1['number_of_discharges']
hrrp_2_2 = hrrp_2.groupby(['provider_id'],as_index=False)[['measure_name']].count().reset_index()
hrrp_2_2.drop(['index'],axis=1, inplace=True)

hrrp_3a = hrrp_2.groupby(['provider_id','start_date','end_date'], as_index=False).apply(my_agg).reset_index()
hrrp_3b = hrrp_2.groupby(['provider_id','start_date','end_date'], as_index=False).apply(my_agg_p).reset_index()
hrrp_3c = hrrp_2.groupby(['provider_id','start_date','end_date'], as_index=False).apply(my_agg_e).reset_index()
hrrp_3b.drop(['start_date','end_date'],axis=1, inplace=True)
hrrp_3c.drop(['start_date','end_date'],axis=1, inplace=True)

hrrp_3 = pd.merge(hrrp_3a,hrrp_3b,on='provider_id')
hrrp_3 = pd.merge(hrrp_3,hrrp_3c,on='provider_id')
hrrp_3 = pd.merge(hrrp_3,hrrp_2_1,on='provider_id')
hrrp_3 = pd.merge(hrrp_3,hrrp_2_2,on='provider_id')

# %%
hrrp_3.head(5)
# Out:
#   provider_id  start_date    end_date  weighted_avg_EXCESS  weighted_avg_PRR  \
# 0      010001  07/01/2014  06/30/2017               1.0468            5.0853
# 1      010005  07/01/2014  06/30/2017               1.0913            5.3414
# 2      010006  07/01/2014  06/30/2017               1.3032            5.6779
# 3      010019  07/01/2014  06/30/2017               1.0077            3.9911
# 4      010023  07/01/2014  06/30/2017               0.9677            4.1218
#
#    weighted_avg_ERR  number_of_discharges  number_of_readmissions  \
# 0            4.8582                 335.0                    18.0
# 1            4.8946                 284.0                    17.0
# 2            4.3570                 431.0                    30.0
# 3            3.9606                 422.0                    17.0
# 4            4.2595                 623.0                    25.0
#
#    raw_avg_readmitrate  measure_name
# 0             0.053731             1
# 1             0.059859             1
# 2             0.069606             1
# 3             0.040284             1
# 4             0.040128             1

# %%
hrrp_2.loc[hrrp_2['provider_id']=='010001']
# Out:
#                       hospital_name provider_id state            measure_name  \
# 4  SOUTHEAST ALABAMA MEDICAL CENTER      010001    AL  READM_30_HIP_KNEE_HRRP
#
#    number_of_discharges  excess_readmission_ratio  predicted_readmission_rate  \
# 4                 335.0                    1.0468                      5.0853
#
#    expected_readmission_rate  number_of_readmissions  start_date    end_date  \
# 4                     4.8582                    18.0  07/01/2014  06/30/2017
#
#   footnote  readmitrate_calc  readmitrate_ratio
# 4      NaN          5.373134           1.056601

# %%
plt.hist(hrrp_3['weighted_avg_PRR'],bins=20);

# %% [markdown]
# ### Wage Index data

# %%
wageindex14 = wageindex14_df.loc[:,['CCN','Case_Mix_Indexes','FY_Wage_Index','3_Year_Avg_Hourly_Wage']]
wageindex14.info()
wageindex14.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3697 entries, 0 to 3696
# Data columns (total 4 columns):
# CCN                       3697 non-null object
# Case_Mix_Indexes          3697 non-null object
# FY_Wage_Index             3697 non-null object
# 3_Year_Avg_Hourly_Wage    3697 non-null object
# dtypes: object(4)
# memory usage: 115.6+ KB
#      CCN Case_Mix_Indexes FY_Wage_Index 3_Year_Avg_Hourly_Wage
# 0  10001           1.7394        0.8106                27.9695
# 1  10005           1.3291         0.815                27.2443
# 2  10006            1.556        0.7436                28.0549
# 3  10007           1.0092        0.7094                22.9586
# 4  10008            0.947        0.7193                25.4392

# %%
wageindex15 = wageindex15_df.loc[:,['CCN','Case_Mix_Indexes','FY_Wage_Index','3_Year_Avg_Hourly_Wage']]
wageindex15.info()
wageindex15.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3641 entries, 0 to 3640
# Data columns (total 4 columns):
# CCN                       3641 non-null object
# Case_Mix_Indexes          3641 non-null object
# FY_Wage_Index             3641 non-null object
# 3_Year_Avg_Hourly_Wage    3641 non-null object
# dtypes: object(4)
# memory usage: 113.9+ KB
#      CCN Case_Mix_Indexes FY_Wage_Index 3_Year_Avg_Hourly_Wage
# 0  10001           1.7647        0.7704                  28.31
# 1  10005           1.3589        0.8212                27.7003
# 2  10006           1.6742        0.7325                28.0827
# 3  10007           1.0283        0.6874                22.5769
# 4  10008           0.9257        0.6973                24.6357

# %%
wageindex16 = wageindex16_df.loc[:,['CCN','Case_Mix_Indexes','FY_Wage_Index','3_Year_Avg_Hourly_Wage']]
wageindex16.info()
wageindex16.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 4 columns):
# CCN                       3633 non-null object
# Case_Mix_Indexes          3460 non-null float64
# FY_Wage_Index             3633 non-null float64
# 3_Year_Avg_Hourly_Wage    3513 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 113.6+ KB
#       CCN  Case_Mix_Indexes  FY_Wage_Index  3_Year_Avg_Hourly_Wage
# 0  010001            1.6935         0.6941                 28.6629
# 1  010005            1.3210         0.8274                 28.0762
# 2  010006            1.6217         0.6875                 27.4785
# 3  010007            1.0092         0.6875                 22.7179
# 4  010008            0.9738         0.6974                 25.1787

# %%
wageindex17 = wageindex17_df.loc[:,['CCN','Case_Mix_Indexes','FY_Wage_Index','3_Year_Avg_Hourly_Wage']]
wageindex17.info()
wageindex17.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3587 entries, 0 to 3586
# Data columns (total 4 columns):
# CCN                       3587 non-null object
# Case_Mix_Indexes          3409 non-null float64
# FY_Wage_Index             3587 non-null float64
# 3_Year_Avg_Hourly_Wage    3480 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 112.2+ KB
#       CCN  Case_Mix_Indexes  FY_Wage_Index  3_Year_Avg_Hourly_Wage
# 0  010001            1.6667         0.7666                 29.0321
# 1  010005            1.3504         0.8099                 28.1724
# 2  010006            1.6484         0.6857                 27.2113
# 3  010007            1.0515         0.6857                 23.5141
# 4  010008            0.9257         0.6977                 25.5438

# %%
# convert to numbers and format CCNs for 6 digits, take average
def clean_wi(file):
    file['CCN'] = ["0"+x if len(x)==5 else x for x in file['CCN']]
    file.replace(['***','**','*',''], np.NaN, inplace=True)
    file['Case_Mix_Indexes'] = file['Case_Mix_Indexes'].astype(float,inplace=True)
    file['FY_Wage_Index'] = file['FY_Wage_Index'].astype(float,inplace=True)
    file['3_Year_Avg_Hourly_Wage'] = file['3_Year_Avg_Hourly_Wage'].astype(float,inplace=True)
    return file

wageindex14 = clean_wi(wageindex14)
wageindex15 = clean_wi(wageindex15)

def drop_nulls(file):
    file = file.dropna().reset_index().drop('index',axis=1)
    return file

wageindex14 = drop_nulls(wageindex14)
wageindex15 = drop_nulls(wageindex15)
wageindex16 = drop_nulls(wageindex16)
wageindex17 = drop_nulls(wageindex17)

# %%
wageindex = pd.concat([wageindex14,wageindex15,wageindex16,wageindex17]).sort_values('CCN')
wageindex.head(10)
# Out:
#       CCN  Case_Mix_Indexes  FY_Wage_Index  3_Year_Avg_Hourly_Wage
# 0  010001            1.7394         0.8106                 27.9695
# 0  010001            1.6935         0.6941                 28.6629
# 0  010001            1.7647         0.7704                 28.3100
# 0  010001            1.6667         0.7666                 29.0321
# 1  010005            1.3210         0.8274                 28.0762
# 1  010005            1.3291         0.8150                 27.2443
# 1  010005            1.3504         0.8099                 28.1724
# 1  010005            1.3589         0.8212                 27.7003
# 2  010006            1.6484         0.6857                 27.2113
# 2  010006            1.6217         0.6875                 27.4785

# %%
wageindex = wageindex.groupby(wageindex['CCN'], as_index=False).mean()
wageindex.head(5)
# Out:
#       CCN  Case_Mix_Indexes  FY_Wage_Index  3_Year_Avg_Hourly_Wage
# 0  010001          1.716075       0.760425               28.493625
# 1  010005          1.339850       0.818375               27.798300
# 2  010006          1.625075       0.712325               27.706850
# 3  010007          1.024550       0.692500               22.941875
# 4  010008          0.943050       0.702925               25.199350

# %%
# plt.hist(wageindex['Case_Mix_Indexes'],bins=20);
# plt.hist(wageindex['FY_2017_Wage_Index'],bins=20);
fig,(ax1,ax2,ax3) = plt.subplots(1,3, figsize=(15,5))
ax1.hist(wageindex['Case_Mix_Indexes'],bins=20)
ax1.set_title('case mix index')
ax2.hist(wageindex['FY_Wage_Index'],bins=20)
ax2.set_title('wage index')
ax3.hist(wageindex['3_Year_Avg_Hourly_Wage'],bins=20)
ax3.set_title('3 yr avg hourly wage');

# %% [markdown]
# ### Census Income data

# %%
def clean_ci(censusincome_df):
    #create county_state column for joining to hospital data
    censusincome_df['state'] = [x[x.find(",")+2:] for x in censusincome_df['Geographic Area Name']]
    censusincome_df['county_pre'] = [x[:x.find(",")].upper() for x in censusincome_df['Geographic Area Name']]
    #remove the words "COUNTY" or "PARISH" in the county name
    censusincome_df['county'] = [x[:x.find(" COUNTY")] if 'COUNTY' in x
                                 else x[:x.find(" PARISH")] if 'PARISH' in x
                                 else "THE DISTRICT" if x=='DISTRICT OF COLUMBIA'
                                 else x 
                                 for x in censusincome_df['county_pre']]
    censusincome_df['state_abbr'] = censusincome_df['state'].map(us_state_abbrev)
    # sum(censusincome_df['state_abbr'].isna())
    censusincome_df['county_st'] = censusincome_df['county']+"_"+censusincome_df['state_abbr']
    censusincome_df['county_st'].value_counts()

    #keep only the median household income column
    censusincome = censusincome_df.loc[:,['county_st','Households!!Estimate!!Median income (dollars)']]
    censusincome.rename(columns = {'Households!!Estimate!!Median income (dollars)':'median_household_income'}, inplace = True)

    return censusincome

censusincome14 = clean_ci(censusincome14_df)
censusincome15 = clean_ci(censusincome15_df)
censusincome16 = clean_ci(censusincome16_df)
censusincome17 = clean_ci(censusincome17_df)

# %%
censusincome = pd.concat([censusincome14,censusincome15,censusincome16,censusincome17]).sort_values('county_st')
censusincome.head(10)

censusincome_check = censusincome['county_st'].value_counts()
censusincome_check.describe()
# Out:
# count    3220.000000
# mean        1.774845
# std         1.310194
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         4.000000
# max         4.000000
# Name: county_st, dtype: float64

# %%
censusincome = censusincome.groupby(censusincome['county_st'],as_index=False).mean()
censusincome.head(5)
# Out:
#       county_st  median_household_income
# 0  ABBEVILLE_SC                  34652.0
# 1     ACADIA_LA                  39837.0
# 2   ACCOMACK_VA                  38503.0
# 3      ADAIR_IA                  48765.0
# 4      ADAIR_KY                  33873.0

# %%
plt.hist(censusincome['median_household_income'],bins=20);

# %% [markdown]
# ### Education level

# %%
# education_df.head(5)
education_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3583 entries, 0 to 3582
# Data columns (total 48 columns):
# FIPS Code                                                                   3204 non-null float64
# State                                                                       3204 non-null object
# Area name                                                                   3204 non-null object
# 2003 Rural-urban Continuum Code                                             3143 non-null float64
# 2003 Urban Influence Code                                                   3143 non-null float64
# 2013 Rural-urban Continuum Code                                             3143 non-null float64
# 2013 Urban Influence Code                                                   3143 non-null float64
# Less than a high school diploma, 1970                                       3186 non-null object
# High school diploma only, 1970                                              3186 non-null object
# Some college (1-3 years), 1970                                              3186 non-null object
# Four years of college or higher, 1970                                       3186 non-null object
# Percent of adults with less than a high school diploma, 1970                3186 non-null float64
# Percent of adults with a high school diploma only, 1970                     3186 non-null float64
# Percent of adults completing some college (1-3 years), 1970                 3186 non-null float64
# Percent of adults completing four years of college or higher, 1970          3186 non-null float64
# Less than a high school diploma, 1980                                       3188 non-null object
# High school diploma only, 1980                                              3188 non-null object
# Some college (1-3 years), 1980                                              3188 non-null object
# Four years of college or higher, 1980                                       3188 non-null object
# Percent of adults with less than a high school diploma, 1980                3188 non-null float64
# Percent of adults with a high school diploma only, 1980                     3188 non-null float64
# Percent of adults completing some college (1-3 years), 1980                 3188 non-null float64
# Percent of adults completing four years of college or higher, 1980          3188 non-null float64
# Less than a high school diploma, 1990                                       3192 non-null object
# High school diploma only, 1990                                              3192 non-null object
# Some college or associate's degree, 1990                                    3192 non-null object
# Bachelor's degree or higher, 1990                                           3192 non-null object
# Percent of adults with less than a high school diploma, 1990                3192 non-null float64
# Percent of adults with a high school diploma only, 1990                     3192 non-null float64
# Percent of adults completing some college or associate's degree, 1990       3191 non-null float64
# Percent of adults with a bachelor's degree or higher, 1990                  3192 non-null float64
# Less than a high school diploma, 2000                                       3193 non-null object
# High school diploma only, 2000                                              3193 non-null object
# Some college or associate's degree, 2000                                    3193 non-null object
# Bachelor's degree or higher, 2000                                           3193 non-null object
# Percent of adults with less than a high school diploma, 2000                3193 non-null float64
# Percent of adults with a high school diploma only, 2000                     3193 non-null float64
# Percent of adults completing some college or associate's degree, 2000       3193 non-null float64
# Percent of adults with a bachelor's degree or higher, 2000                  3193 non-null float64
# Less than a high school diploma, 2013-17                                    3194 non-null object
# High school diploma only, 2013-17                                           3194 non-null object
# Some college or associate's degree, 2013-17                                 3194 non-null object
# Bachelor's degree or higher, 2013-17                                        3194 non-null object
# Percent of adults with less than a high school diploma, 2013-17             3194 non-null float64
# Percent of adults with a high school diploma only, 2013-17                  3194 non-null float64
# Percent of adults completing some college or associate's degree, 2013-17    3194 non-null float64
# Percent of adults with a bachelor's degree or higher, 2013-17               3194 non-null float64
# Unnamed: 47                                                                 0 non-null float64
# dtypes: float64(26), object(22)
# memory usage: 1.3+ MB

# %%
education_df = education_df.dropna(subset = ['Area name'])
education_df.shape
# Out:
# (3204, 48)

# %%
def clean_edu(education_df):
    #create county_state column for joining to hospital data
#     education_df['area_name'] = [x for x in education_df['Area name']]
    education_df['county_pre'] = [x.upper() for x in education_df['Area name']]
    #remove the words "COUNTY" or "PARISH" in the county name
    education_df['county'] = [x[:x.find(" COUNTY")] if 'COUNTY' in x
                                 else x[:x.find(" PARISH")] if 'PARISH' in x
                                 else "THE DISTRICT" if x=='DISTRICT OF COLUMBIA'
                                 else x 
                                 for x in education_df['county_pre']]
    education_df['county_st'] = education_df['county']+"_"+education_df['State']
    #create education variable
    education_df['some_college_or_higher'] = education_df["Percent of adults completing some college or associate's degree, 2013-17"]+education_df["Percent of adults with a bachelor's degree or higher, 2013-17"]
    #keep only the median household income column
    education = education_df.loc[:,['county_st','some_college_or_higher']]
    education = education.dropna(subset = ['some_college_or_higher'])
#     education.rename(columns = {'Households!!Estimate!!Median income (dollars)':'median_household_income'}, inplace = True)

    return education

education = clean_edu(education_df)

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3194 entries, 0 to 3203
# Data columns (total 2 columns):
# county_st                 3194 non-null object
# some_college_or_higher    3194 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 74.9+ KB

# %% [markdown]
# ### Join data

# %%
#join readmit info to general hospital info

hosp = pd.merge(hrrp_3,geninfo,on='provider_id')
hosp = pd.merge(hosp,wageindex,left_on='provider_id',right_on='CCN').drop('CCN',axis=1)
hosp = pd.merge(hosp,censusincome,on='county_st') # use how='left' if you want to check which ones dropped
hosp = pd.merge(hosp,education,on='county_st') # use how='left' if you want to check which ones dropped


hosp1 = hosp.copy()

hosp.info()
hosp.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 1286
# Data columns (total 30 columns):
# provider_id                                             1287 non-null object
# start_date                                              1287 non-null object
# end_date                                                1287 non-null object
# weighted_avg_EXCESS                                     1287 non-null float64
# weighted_avg_PRR                                        1287 non-null float64
# weighted_avg_ERR                                        1287 non-null float64
# number_of_discharges                                    1287 non-null float64
# number_of_readmissions                                  1287 non-null float64
# raw_avg_readmitrate                                     1287 non-null float64
# measure_name                                            1287 non-null int64
# hospital_name                                           1287 non-null object
# state                                                   1287 non-null object
# zip_code                                                1287 non-null object
# county_name                                             1287 non-null object
# hospital_type                                           1287 non-null object
# hospital_ownership                                      1287 non-null object
# emergency_services                                      1287 non-null bool
# hospital_overall_rating                                 1287 non-null object
# mortality_national_comparison                           1287 non-null object
# safety_of_care_national_comparison                      1287 non-null object
# patient_experience_national_comparison                  1287 non-null object
# effectiveness_of_care_national_comparison               1287 non-null object
# timeliness_of_care_national_comparison                  1287 non-null object
# efficient_use_of_medical_imaging_national_comparison    1287 non-null object
# county_st                                               1287 non-null object
# Case_Mix_Indexes                                        1287 non-null float64
# FY_Wage_Index                                           1287 non-null float64
# 3_Year_Avg_Hourly_Wage                                  1287 non-null float64
# median_household_income                                 1287 non-null float64
# some_college_or_higher                                  1287 non-null float64
# dtypes: bool(1), float64(11), int64(1), object(17)
# memory usage: 302.9+ KB
#   provider_id  start_date    end_date  weighted_avg_EXCESS  weighted_avg_PRR  \
# 0      010001  07/01/2014  06/30/2017               1.0468            5.0853
# 1      010055  07/01/2014  06/30/2017               1.0961            4.3096
# 2      010005  07/01/2014  06/30/2017               1.0913            5.3414
# 3      010006  07/01/2014  06/30/2017               1.3032            5.6779
# 4      010019  07/01/2014  06/30/2017               1.0077            3.9911
#
#    weighted_avg_ERR  number_of_discharges  number_of_readmissions  \
# 0            4.8582                 335.0                    18.0
# 1            3.9316                 490.0                    23.0
# 2            4.8946                 284.0                    17.0
# 3            4.3570                 431.0                    30.0
# 4            3.9606                 422.0                    17.0
#
#    raw_avg_readmitrate  measure_name  ...  \
# 0             0.053731             1  ...
# 1             0.046939             1  ...
# 2             0.059859             1  ...
# 3             0.069606             1  ...
# 4             0.040284             1  ...
#
#   patient_experience_national_comparison  \
# 0             Below the national average
# 1           Same as the national average
# 2           Same as the national average
# 3             Below the national average
# 4           Same as the national average
#
#   effectiveness_of_care_national_comparison  \
# 0              Same as the national average
# 1              Same as the national average
# 2                Above the national average
# 3              Same as the national average
# 4              Same as the national average
#
#   timeliness_of_care_national_comparison  \
# 0             Above the national average
# 1             Above the national average
# 2             Above the national average
# 3             Above the national average
# 4             Above the national average
#
#   efficient_use_of_medical_imaging_national_comparison      county_st  \
# 0                       Same as the national average       HOUSTON_AL
# 1                         Above the national average       HOUSTON_AL
# 2                         Below the national average      MARSHALL_AL
# 3                         Below the national average    LAUDERDALE_AL
# 4                         Below the national average       COLBERT_AL
#
#   Case_Mix_Indexes  FY_Wage_Index 3_Year_Avg_Hourly_Wage  \
# 0         1.716075       0.760425              28.493625
# 1         1.647400       0.754950              28.620800
# 2         1.339850       0.818375              27.798300
# 3         1.625075       0.712325              27.706850
# 4         1.361075       0.712325              28.494000
#
#   median_household_income some_college_or_higher
# 0                42392.50                   53.4
# 1                42392.50                   53.4
# 2                38819.50                   48.7
# 3                42973.75                   50.6
# 4                43786.00                   50.2
#
# [5 rows x 30 columns]

# %%
## CHECKING
# check = hosp.loc[hosp['median_household_income'].isna()]
# check['county_st'].value_counts()
# # check.head(5)

# fragment='DISTRICT'

# # censusincome[censusincome['county_st'].str.contains(fragment)]
# censusincome_df[censusincome_df['county'].str.contains(fragment)]

# hosp[hosp['county_st'].str.contains(fragment)]

# geninfo_df[geninfo['state'].str.contains(fragment)]

# %% [markdown]
# ### Final cleaning and creation of dummy variables

# %%
plt.scatter(hosp1['hospital_overall_rating'],hosp1['weighted_avg_PRR'],alpha=0.1);

# %%
plt.hist(hosp['weighted_avg_PRR'],bins=20);
#remove left tails

# %%
hosp['hospital_ownership'].value_counts()
# Out:
# Voluntary non-profit - Private                 657
# Proprietary                                    209
# Voluntary non-profit - Other                   132
# Voluntary non-profit - Church                  132
# Government - Hospital District or Authority     80
# Government - Local                              35
# Physician                                       23
# Government - State                              17
# Government - Federal                             2
# Name: hospital_ownership, dtype: int64

# %%
hosp['hospital_type'].value_counts()
#do not need to inclue hospital_type as categorical variable - only acute care hospitals in the final dataset
# Out:
# Acute Care Hospitals    1287
# Name: hospital_type, dtype: int64

# %%
hosp['emergency_services'].value_counts()
# Out:
# True     1216
# False      71
# Name: emergency_services, dtype: int64

# %%
hosp['hospital_overall_rating'].value_counts()
#leave for now, may drop the N/As if it's not a useful predictor
# Out:
# 3                356
# 4                317
# 2                278
# 5                180
# 1                115
# Not Available     41
# Name: hospital_overall_rating, dtype: int64

# %%
hosp['mortality_national_comparison'].value_counts()
#leave for now, may drop the N/As if it's not a useful predictor
# Out:
# Same as the national average    731
# Above the national average      252
# Below the national average      222
# Not Available                    82
# Name: mortality_national_comparison, dtype: int64

# %%
# drop low PRRs to avoid left tail
#hosp = hosp.loc[hosp['weighted_avg_PRR'] >=5]
hosp = hosp.loc[hosp['3_Year_Avg_Hourly_Wage'].isna()==False]
hosp = hosp.loc[hosp['hospital_overall_rating'] != 'Not Available']
hosp = hosp.loc[hosp['mortality_national_comparison'] != 'Not Available']

#reduces observations by several hundred- consider not keeping
hosp = hosp.loc[hosp['safety_of_care_national_comparison'] != 'Not Available']
hosp = hosp.loc[hosp['patient_experience_national_comparison'] != 'Not Available']
hosp = hosp.loc[hosp['effectiveness_of_care_national_comparison'] != 'Not Available']
hosp = hosp.loc[hosp['timeliness_of_care_national_comparison'] != 'Not Available']
hosp = hosp.loc[hosp['efficient_use_of_medical_imaging_national_comparison'] != 'Not Available']

#Create categorical variables
# hosp['hospital_type'].value_counts()
hosp = pd.get_dummies(hosp, columns=['emergency_services','hospital_ownership','hospital_overall_rating',
                                     'mortality_national_comparison','safety_of_care_national_comparison',
                                     'patient_experience_national_comparison',
                                     'effectiveness_of_care_national_comparison',
                                     'timeliness_of_care_national_comparison',
                                     'efficient_use_of_medical_imaging_national_comparison'],drop_first=True)
hosp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1188 entries, 0 to 1286
# Data columns (total 45 columns):
# provider_id                                                                          1188 non-null object
# start_date                                                                           1188 non-null object
# end_date                                                                             1188 non-null object
# weighted_avg_EXCESS                                                                  1188 non-null float64
# weighted_avg_PRR                                                                     1188 non-null float64
# weighted_avg_ERR                                                                     1188 non-null float64
# number_of_discharges                                                                 1188 non-null float64
# number_of_readmissions                                                               1188 non-null float64
# raw_avg_readmitrate                                                                  1188 non-null float64
# measure_name                                                                         1188 non-null int64
# hospital_name                                                                        1188 non-null object
# state                                                                                1188 non-null object
# zip_code                                                                             1188 non-null object
# county_name                                                                          1188 non-null object
# hospital_type                                                                        1188 non-null object
# county_st                                                                            1188 non-null object
# Case_Mix_Indexes                                                                     1188 non-null float64
# FY_Wage_Index                                                                        1188 non-null float64
# 3_Year_Avg_Hourly_Wage                                                               1188 non-null float64
# median_household_income                                                              1188 non-null float64
# some_college_or_higher                                                               1188 non-null float64
# emergency_services_True                                                              1188 non-null uint8
# hospital_ownership_Government - Hospital District or Authority                       1188 non-null uint8
# hospital_ownership_Government - Local                                                1188 non-null uint8
# hospital_ownership_Government - State                                                1188 non-null uint8
# hospital_ownership_Proprietary                                                       1188 non-null uint8
# hospital_ownership_Voluntary non-profit - Church                                     1188 non-null uint8
# hospital_ownership_Voluntary non-profit - Other                                      1188 non-null uint8
# hospital_ownership_Voluntary non-profit - Private                                    1188 non-null uint8
# hospital_overall_rating_2                                                            1188 non-null uint8
# hospital_overall_rating_3                                                            1188 non-null uint8
# hospital_overall_rating_4                                                            1188 non-null uint8
# hospital_overall_rating_5                                                            1188 non-null uint8
# mortality_national_comparison_Below the national average                             1188 non-null uint8
# mortality_national_comparison_Same as the national average                           1188 non-null uint8
# safety_of_care_national_comparison_Below the national average                        1188 non-null uint8
# safety_of_care_national_comparison_Same as the national average                      1188 non-null uint8
# patient_experience_national_comparison_Below the national average                    1188 non-null uint8
# patient_experience_national_comparison_Same as the national average                  1188 non-null uint8
# effectiveness_of_care_national_comparison_Below the national average                 1188 non-null uint8
# effectiveness_of_care_national_comparison_Same as the national average               1188 non-null uint8
# timeliness_of_care_national_comparison_Below the national average                    1188 non-null uint8
# timeliness_of_care_national_comparison_Same as the national average                  1188 non-null uint8
# efficient_use_of_medical_imaging_national_comparison_Below the national average      1188 non-null uint8
# efficient_use_of_medical_imaging_national_comparison_Same as the national average    1188 non-null uint8
# dtypes: float64(11), int64(1), object(9), uint8(24)
# memory usage: 232.0+ KB

# %% [markdown]
# ### EDA with updated dataset

# %%
plt.hist(hosp['weighted_avg_PRR'],bins=20);

# %%
plt.hist(hosp['number_of_discharges'],bins=20);

# %%
plt.figure(figsize=(8,8))
plt.scatter(hosp['3_Year_Avg_Hourly_Wage'],hosp['weighted_avg_PRR'],alpha=0.1)
plt.xlabel('average hourly wage')
plt.ylabel('readmit rate');

# %%
plt.figure(figsize=(8,8))
plt.scatter(hosp['FY_Wage_Index'],hosp['weighted_avg_PRR'],alpha=0.1)
plt.xlabel('wage index')
plt.ylabel('readmit rate');

# %%
plt.figure(figsize=(8,8))
plt.scatter(hosp['Case_Mix_Indexes'],hosp['weighted_avg_PRR'],alpha=0.1)
plt.xlabel('wage')
plt.ylabel('readmit rate');

# %%
plt.figure(figsize=(8,8))
plt.scatter(hosp['median_household_income'],hosp['FY_Wage_Index'],alpha=0.1)
plt.xlabel('median income')
plt.ylabel('wage index');

# %%
with open('hosp.pickle', 'wb') as to_write:
    pickle.dump(hosp, to_write)

# %% [markdown]
# ### Scratchwork

# %%
#hosp 

def my_agg2(x):
    names = {'avg_county_ERR': (x['weighted_avg_ERR']).sum()/x['provider_id'].count()}
    return pd.Series(names, index=['avg_county_ERR'])

hosp2 = hosp.groupby(['county_st','median_household_income'],as_index=False)['weighted_avg_ERR'].mean().reset_index().drop(["index"], axis=1)
hosp2.shape
hosp2.head(5)
            

# hrrp_2_1 = hrrp_2.groupby(['provider_id'])[['number_of_discharges','number_of_readmissions']].sum()
# hrrp_2_1['raw_avg_readmitrate'] = hrrp_2_1['number_of_readmissions']/hrrp_2_1['number_of_discharges']
# hrrp_3 = hrrp_2.groupby(['provider_id','start_date','end_date'], as_index=False).apply(my_agg).reset_index()
# hrrp_3 = pd.merge(hrrp_3,hrrp_2_1,on='provider_id')
# hrrp_3.shape

# %%
plt.figure(figsize=(8,8))
plt.scatter(hosp2['median_household_income'],hosp2['weighted_avg_ERR'],alpha=0.1)
plt.xlabel('median income')
plt.ylabel('wage index by county');

# %%
plt.hist(hrrp_df['predicted_readmission_rate'],bins=20);

# %%
plt.hist(hosp['weighted_avg_PRR'])

# %%
plt.scatter(hosp['number_of_discharges'],hosp['weighted_avg_PRR'],alpha=0.2)

# %%
hosp_low = hosp.loc[hosp['weighted_avg_PRR'] < 5]
plt.scatter(hosp_low['FY_2017_Wage_Index'],hosp_low['weighted_avg_PRR'],alpha=0.2)

# %%
hosp_high = hosp.loc[hosp['weighted_avg_PRR'] >= 5]
plt.scatter(hosp_high['FY_2017_Wage_Index'],hosp_high['weighted_avg_PRR'],alpha=0.2)

# %%
#testing correlation
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(hosp_high.iloc[:,-1:],hosp_high['weighted_avg_PRR'])

lr.score(hosp_high.iloc[:,-1:],hosp_high['weighted_avg_PRR'])

# %%
hosp_low['measure_name'].value_counts()
hosp_low.head(5)

# %%
hosp_high['measure_name'].value_counts()

# %%
hrrp_df.loc[hrrp_df['provider_id']=='030107']

# %%
# import patsy

# test2=patsy.dmatrix('emergency_services',data=hosp,return_type='dataframe')

# %%
hosp.head(5)

# %%
hosp.info()

# %%
#hosp['mortality_national_comparison'].value_counts()
