# %%
import json

# %%
# a1 = 564344
a1= 1560200
# a1 = 2250603
# load dictionary
with open('sephora_products/product'+str(a1)+'.json', 'r') as fp:
    tests = json.load(fp)

# %%
tests
# Out:
# {'product_id': '1560200',
#  'url': 'https://www.sephora.com/product/cleanser-P381436',
#  'brand': 'Eve Lom',
#  'name': 'Cleanser',
#  'review_count': '620 reviews',
#  'love_count': '20K loves',
#  'price': '$80.00',
# ...

# %%
len(tests['top_helpful_reviews'])
# Out:
# 60

# %%
10*random.random()
# Out:
# 8.67327168609749
