# %% [markdown]
# ### EDA
# Created variables defining appointment history for patients and performed EDA. Output several datasets with different appointments for later model exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import calendar
import pickle

# %matplotlib inline
plt.style.use('seaborn-pastel')

import seaborn as sns
sns.set(style="whitegrid")

# %run EDA_functions.py

# %%
with open('pickles/appt.pickle','rb') as read_file:
    a_df = pickle.load(read_file)

# %% [markdown]
# ### Create alternative dataset that only contains appointments with historical data

# %%
a_df.head(5)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 1  7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 2  3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 3  7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 4  7.345362e+14        5630213      F  2016-04-27T14:58:11Z
#
#          AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   76       REPÚBLICA            0             1
# 1  2016-04-29T00:00:00Z   23      GOIABEIRAS            0             0
# 2  2016-04-29T00:00:00Z   39      GOIABEIRAS            0             0
# 3  2016-04-29T00:00:00Z   19       CONQUISTA            0             0
# 4  2016-04-29T00:00:00Z   30  NOVA PALESTINA            0             0
#
#    Diabetes  ...   SchedDay  SchedTime  SchedDayofWeek    ApptDay  \
# 0         0  ... 2016-04-27   08:36:51       Wednesday 2016-04-29
# 1         0  ... 2016-04-27   15:05:12       Wednesday 2016-04-29
# 2         0  ... 2016-04-27   15:39:58       Wednesday 2016-04-29
# 3         0  ... 2016-04-27   12:48:25       Wednesday 2016-04-29
# 4         0  ... 2016-04-27   14:58:11       Wednesday 2016-04-29
#
#    ApptDayofWeek DayDiff Handcap_bin DayDiff2 Age2  Neighbourhood2
# 0         Friday       2           0        2   76       REPÚBLICA
# 1         Friday       2           0        2   23      GOIABEIRAS
# 2         Friday       2           0        2   39      GOIABEIRAS
# 3         Friday       2           0        2   19       CONQUISTA
# 4         Friday       2           0        2   30  NOVA PALESTINA
#
# [5 rows x 25 columns]

# %%
a_df2 = a_df.copy()
a_df2.sort_values(['PatientId','ApptDay'],inplace=True)
#days elapsed since prior appointment
a_df2['ApptDayDiff'] = a_df2.groupby(['PatientId'])[['ApptDay']].diff()
#date of prior appointment
a_df2['PrevApptDay'] = a_df2.groupby(['PatientId'])[['ApptDay']].shift()
#missed prior appointment
a_df2['PrevAppt_No_show'] = a_df2.groupby(['PatientId'])[['No_show_num']].shift()
#days elapsed between prior appt and current scheduled appt
a_df2['PrevAppt_Sched_diff'] = a_df2['SchedDay'] - a_df2['PrevApptDay']

# %%
#proportion of prior appointments that had been missed (rolling proportion)
a_df2['appt_count'] = 1
a_df2['total_appt_count'] = a_df2.groupby(['PatientId'])['appt_count'].cumsum()
a_df2['total_no_show_count'] = a_df2.groupby(['PatientId'])['No_show_num'].cumsum()
a_df2['no_show_rate'] = a_df2['total_no_show_count']/a_df2['total_appt_count']
a_df2['no_show_rate2'] = a_df2.groupby(['PatientId'])['no_show_rate'].shift() # rate of prior appointments
a_df2['prior_appt_count'] = a_df2.groupby(['PatientId'])['total_appt_count'].shift() # number of prior appointments
a_df2['prior_no_show_count'] = a_df2.groupby(['PatientId'])['total_no_show_count'].shift() # number of prior appointments

# %%
a_df2[['PatientId','ApptDay','ApptDayDiff','No_show_num','total_appt_count','total_no_show_count','prior_appt_count','prior_no_show_count','no_show_rate','no_show_rate2']][19:35]
# Out:
#          PatientId    ApptDay ApptDayDiff  No_show_num  total_appt_count  \
# 19174  142133299.0 2016-05-16         NaT            1                 1
# 67501  142133299.0 2016-06-07     22 days            0                 2
# 29793  178168233.0 2016-05-02         NaT            0                 1
# 18327  179874775.0 2016-05-24         NaT            1                 1
# 46038  188964456.0 2016-05-18         NaT            0                 1
# 58107  211124677.0 2016-06-02         NaT            0                 1
# 58342  211124677.0 2016-06-08      6 days            0                 2
# 44897  215778678.0 2016-05-02         NaT            1                 1
# 29729  243921212.0 2016-05-03         NaT            0                 1
# 32867  251541539.0 2016-05-13         NaT            1                 1
# 11262  251541539.0 2016-05-19      6 days            0                 2
# 70574  251541539.0 2016-06-01     13 days            0                 3
# 1235   253866521.0 2016-04-29         NaT            0                 1
# 38169  274297149.0 2016-05-18         NaT            0                 1
# 487    318385314.0 2016-04-29         NaT            0                 1
# 34285  319947764.0 2016-05-19         NaT            0                 1
#
#        total_no_show_count  prior_appt_count  prior_no_show_count  \
# 19174                    1               NaN                  NaN
# 67501                    1               1.0                  1.0
# 29793                    0               NaN                  NaN
# 18327                    1               NaN                  NaN
# 46038                    0               NaN                  NaN
# 58107                    0               NaN                  NaN
# 58342                    0               1.0                  0.0
# 44897                    1               NaN                  NaN
# 29729                    0               NaN                  NaN
# 32867                    1               NaN                  NaN
# 11262                    1               1.0                  1.0
# 70574                    1               2.0                  1.0
# 1235                     0               NaN                  NaN
# 38169                    0               NaN                  NaN
# 487                      0               NaN                  NaN
# 34285                    0               NaN                  NaN
#
#        no_show_rate  no_show_rate2
# 19174      1.000000            NaN
# 67501      0.500000            1.0
# 29793      0.000000            NaN
# 18327      1.000000            NaN
# 46038      0.000000            NaN
# 58107      0.000000            NaN
# 58342      0.000000            0.0
# 44897      1.000000            NaN
# 29729      0.000000            NaN
# 32867      1.000000            NaN
# 11262      0.500000            1.0
# 70574      0.333333            0.5
# 1235       0.000000            NaN
# 38169      0.000000            NaN
# 487        0.000000            NaN
# 34285      0.000000            NaN

# %%
a_df2.shape
# Out:
# (71163, 36)

# %%
def resched(x):
    if x['PrevAppt_No_show'] == 1 and x['PrevAppt_Sched_diff'] == dt.timedelta(0):
        return 1
    else:
        return 0
    
def followup(x):
    if x['PrevAppt_No_show'] == 0 and x['PrevAppt_Sched_diff'] == dt.timedelta(0):
        return 1
    else:
        return 0

# %%
# categorizing the visit types
# a true "reschedule" - they missed their prior appointment and rescheduled it on the same day as their prior appointment
a_df2['Reschedule'] = a_df2.apply(resched,axis=1)
# a "follow-up" - they attended their prior appointment and they scheduled the current one on the same day
a_df2['Follow_up'] = a_df2.apply(followup,axis=1)

# %%
a_df2['ApptDayDiff'] = [x.days for x in a_df2['ApptDayDiff']]
a_df2['PrevAppt_Sched_diff'] = [x.days for x in a_df2['PrevAppt_Sched_diff']]

# %%
# identify all patients with more than 1 appointment
a_df2a = a_df2.groupby(['PatientId'],as_index=False)[['No_show']].count()
a_df2b = a_df2a.loc[a_df2a['No_show']>1]
print(a_df2b.shape)
a_df2b.head(5)
# Out:
# (14531, 2)
#       PatientId  No_show
# 4    22638656.0        2
# 8    64851211.0        2
# 14  122451254.0        2
# 16  142133299.0        2
# 20  211124677.0        2

# %%
# keep only appointments for patients with more than 1 appointment
a_df3 = a_df2.merge(a_df2b['PatientId'],how='inner',left_on = 'PatientId',right_on = 'PatientId')
print(a_df3.shape)
a_df3.head(10)
# Out:
# (39984, 38)
#      PatientId  AppointmentID Gender          ScheduledDay  \
# 0   22638656.0        5580835      F  2016-04-14T07:23:30Z
# 1   22638656.0        5715081      F  2016-05-18T13:37:12Z
# 2   64851211.0        5683383      F  2016-05-11T07:28:23Z
# 3   64851211.0        5697532      F  2016-05-13T16:22:26Z
# 4  122451254.0        5556646      M  2016-04-07T12:39:53Z
# 5  122451254.0        5576521      M  2016-04-13T08:35:28Z
# 6  142133299.0        5683430      F  2016-05-11T07:31:01Z
# 7  142133299.0        5767863      F  2016-06-03T07:09:49Z
# 8  211124677.0        5741812      M  2016-05-30T07:27:04Z
# 9  211124677.0        5761936      M  2016-06-02T07:13:31Z
#
#          AppointmentDay  Age        Neighbourhood  Scholarship  Hipertension  \
# 0  2016-05-03T00:00:00Z   22           INHANGUETÁ            0             0
# 1  2016-06-08T00:00:00Z   23           INHANGUETÁ            0             0
# 2  2016-05-13T00:00:00Z   29              MARUÍPE            0             0
# 3  2016-05-17T00:00:00Z   29              MARUÍPE            0             0
# 4  2016-05-02T00:00:00Z   28    JESUS DE NAZARETH            0             0
# 5  2016-05-09T00:00:00Z   28    JESUS DE NAZARETH            0             0
# 6  2016-05-16T00:00:00Z   80  ARIOVALDO FAVALESSA            0             1
# 7  2016-06-07T00:00:00Z   80  ARIOVALDO FAVALESSA            0             1
# 8  2016-06-02T00:00:00Z   56          SANTOS REIS            0             0
# 9  2016-06-08T00:00:00Z   56          SANTOS REIS            0             0
#
#    Diabetes  ...  PrevAppt_Sched_diff  appt_count  total_appt_count  \
# 0         0  ...                  NaN           1                 1
# 1         0  ...                 15.0           1                 2
# 2         0  ...                  NaN           1                 1
# 3         0  ...                  0.0           1                 2
# 4         0  ...                  NaN           1                 1
# 5         0  ...                -19.0           1                 2
# 6         0  ...                  NaN           1                 1
# 7         0  ...                 18.0           1                 2
# 8         0  ...                  NaN           1                 1
# 9         0  ...                  0.0           1                 2
#
#   total_no_show_count  no_show_rate no_show_rate2 prior_appt_count  \
# 0                   0           0.0           NaN              NaN
# 1                   0           0.0           0.0              1.0
# 2                   1           1.0           NaN              NaN
# 3                   1           0.5           1.0              1.0
# 4                   1           1.0           NaN              NaN
# 5                   2           1.0           1.0              1.0
# 6                   1           1.0           NaN              NaN
# 7                   1           0.5           1.0              1.0
# 8                   0           0.0           NaN              NaN
# 9                   0           0.0           0.0              1.0
#
#   prior_no_show_count Reschedule Follow_up
# 0                 NaN          0         0
# 1                 0.0          0         0
# 2                 NaN          0         0
# 3                 1.0          1         0
# 4                 NaN          0         0
# 5                 1.0          0         0
# 6                 NaN          0         0
# 7                 1.0          0         0
# 8                 NaN          0         0
# 9                 0.0          0         1
#
# [10 rows x 38 columns]

# %%
#drop the first appointments
a_df4 = a_df3.loc[a_df3['PrevApptDay'].isna() == False]

# %%
a_df4.shape
# Out:
# (25453, 38)

# %%
a_df4.head(10)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 1    22638656.0        5715081      F  2016-05-18T13:37:12Z
# 3    64851211.0        5697532      F  2016-05-13T16:22:26Z
# 5   122451254.0        5576521      M  2016-04-13T08:35:28Z
# 7   142133299.0        5767863      F  2016-06-03T07:09:49Z
# 9   211124677.0        5761936      M  2016-06-02T07:13:31Z
# 11  251541539.0        5692489      F  2016-05-12T15:29:02Z
# 12  251541539.0        5721140      F  2016-05-19T15:31:13Z
# 14  355744126.0        5732684      M  2016-05-24T12:13:17Z
# 16  422861257.0        5707143      F  2016-05-17T09:13:43Z
# 17  422861257.0        5779051      F  2016-06-06T17:37:40Z
#
#           AppointmentDay  Age        Neighbourhood  Scholarship  Hipertension  \
# 1   2016-06-08T00:00:00Z   23           INHANGUETÁ            0             0
# 3   2016-05-17T00:00:00Z   29              MARUÍPE            0             0
# 5   2016-05-09T00:00:00Z   28    JESUS DE NAZARETH            0             0
# 7   2016-06-07T00:00:00Z   80  ARIOVALDO FAVALESSA            0             1
# 9   2016-06-08T00:00:00Z   56          SANTOS REIS            0             0
# 11  2016-05-19T00:00:00Z   85              MARUÍPE            0             1
# 12  2016-06-01T00:00:00Z   85              MARUÍPE            0             1
# 14  2016-06-03T00:00:00Z   81           TABUAZEIRO            0             0
# 16  2016-05-19T00:00:00Z   30           CRUZAMENTO            1             0
# 17  2016-06-08T00:00:00Z   30           CRUZAMENTO            1             0
#
#     Diabetes  ...  PrevAppt_Sched_diff  appt_count  total_appt_count  \
# 1          0  ...                 15.0           1                 2
# 3          0  ...                  0.0           1                 2
# 5          0  ...                -19.0           1                 2
# 7          0  ...                 18.0           1                 2
# 9          0  ...                  0.0           1                 2
# 11         0  ...                 -1.0           1                 2
# 12         0  ...                  0.0           1                 3
# 14         0  ...                 -8.0           1                 2
# 16         0  ...                 15.0           1                 2
# 17         0  ...                 18.0           1                 3
#
#    total_no_show_count  no_show_rate no_show_rate2 prior_appt_count  \
# 1                    0      0.000000           0.0              1.0
# 3                    1      0.500000           1.0              1.0
# 5                    2      1.000000           1.0              1.0
# 7                    1      0.500000           1.0              1.0
# 9                    0      0.000000           0.0              1.0
# 11                   1      0.500000           1.0              1.0
# 12                   1      0.333333           0.5              2.0
# 14                   1      0.500000           0.0              1.0
# 16                   0      0.000000           0.0              1.0
# 17                   0      0.000000           0.0              2.0
#
#    prior_no_show_count Reschedule Follow_up
# 1                  0.0          0         0
# 3                  1.0          1         0
# 5                  1.0          0         0
# 7                  1.0          0         0
# 9                  0.0          0         1
# 11                 1.0          0         0
# 12                 1.0          0         1
# 14                 0.0          0         0
# 16                 0.0          0         0
# 17                 0.0          0         0
#
# [10 rows x 38 columns]

# %%
test = a_df4[['no_show_rate2','Reschedule']]
test.drop_duplicates()
test.loc[(test['no_show_rate2'] < 0) & (test['Reschedule'] == 1)]
# Out:
# Empty DataFrame
# Columns: [no_show_rate2, Reschedule]
# Index: []

# %%
with open('pickles/appt_v2_all.pickle', 'wb') as to_write:
    pickle.dump(a_df2, to_write)

# %%
with open('pickles/appt_v2.pickle', 'wb') as to_write:
    pickle.dump(a_df4, to_write)

# %% [markdown]
# ### Create alternative dataset that only contains one-time appointments

# %%
# identify all patients with just 1 appointment
a_df2c = a_df2a.loc[a_df2a['No_show']==1]
print(a_df2c.shape)
a_df2c.head(5)
# Out:
# (31179, 2)
#       PatientId  No_show
# 0  3.921784e+04        1
# 1  1.417242e+05        1
# 2  5.376153e+05        1
# 3  5.628261e+06        1
# 5  5.216894e+07        1

# %%
# keep only appointments for patients with 1 appointment
a_df5 = a_df2.merge(a_df2c['PatientId'],how='inner',left_on = 'PatientId',right_on = 'PatientId')
a_df5.drop(columns=['ApptDayDiff','PrevApptDay','PrevAppt_No_show','PrevAppt_Sched_diff'],inplace=True)
print(a_df5.shape)
a_df5.head(10)
# Out:
# (31179, 34)
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  3.921784e+04        5751990      F  2016-05-31T10:56:41Z
# 1  1.417242e+05        5637648      M  2016-04-29T07:13:36Z
# 2  5.376153e+05        5637728      F  2016-04-29T07:19:57Z
# 3  5.628261e+06        5680449      M  2016-05-10T11:58:18Z
# 4  5.216894e+07        5607220      F  2016-04-20T11:22:15Z
# 5  5.422400e+07        5613714      M  2016-04-25T09:36:18Z
# 6  6.249793e+07        5671723      M  2016-05-09T07:05:33Z
# 7  7.838548e+07        5640016      F  2016-04-29T09:59:11Z
# 8  7.922850e+07        5743266      F  2016-05-30T08:51:07Z
# 9  8.658474e+07        5672306      M  2016-05-09T07:54:13Z
#
#          AppointmentDay  Age    Neighbourhood  Scholarship  Hipertension  \
# 0  2016-06-03T00:00:00Z   44     PRAIA DO SUÁ            0             0
# 1  2016-05-02T00:00:00Z   12   FORTE SÃO JOÃO            0             0
# 2  2016-05-06T00:00:00Z   14   FORTE SÃO JOÃO            0             0
# 3  2016-05-13T00:00:00Z   13   PARQUE MOSCOSO            0             0
# 4  2016-05-17T00:00:00Z   28  JARDIM DA PENHA            0             0
# 5  2016-05-11T00:00:00Z   32          ITARARÉ            0             0
# 6  2016-05-11T00:00:00Z   10  JARDIM DA PENHA            0             0
# 7  2016-05-02T00:00:00Z   21        CARATOÍRA            0             0
# 8  2016-06-08T00:00:00Z   21   NOVA PALESTINA            0             0
# 9  2016-05-13T00:00:00Z   68        CARATOÍRA            0             0
#
#    Diabetes  ...   Neighbourhood2  appt_count  total_appt_count  \
# 0         0  ...     PRAIA DO SUÁ           1                 1
# 1         0  ...   FORTE SÃO JOÃO           1                 1
# 2         0  ...   FORTE SÃO JOÃO           1                 1
# 3         0  ...   PARQUE MOSCOSO           1                 1
# 4         0  ...  JARDIM DA PENHA           1                 1
# 5         0  ...          ITARARÉ           1                 1
# 6         0  ...  JARDIM DA PENHA           1                 1
# 7         0  ...        CARATOÍRA           1                 1
# 8         0  ...   NOVA PALESTINA           1                 1
# 9         0  ...        CARATOÍRA           1                 1
#
#   total_no_show_count  no_show_rate no_show_rate2 prior_appt_count  \
# 0                   0           0.0           NaN              NaN
# 1                   0           0.0           NaN              NaN
# 2                   0           0.0           NaN              NaN
# 3                   1           1.0           NaN              NaN
# 4                   0           0.0           NaN              NaN
# 5                   0           0.0           NaN              NaN
# 6                   0           0.0           NaN              NaN
# 7                   0           0.0           NaN              NaN
# 8                   0           0.0           NaN              NaN
# 9                   0           0.0           NaN              NaN
#
#   prior_no_show_count Reschedule Follow_up
# 0                 NaN          0         0
# 1                 NaN          0         0
# 2                 NaN          0         0
# 3                 NaN          0         0
# 4                 NaN          0         0
# 5                 NaN          0         0
# 6                 NaN          0         0
# 7                 NaN          0         0
# 8                 NaN          0         0
# 9                 NaN          0         0
#
# [10 rows x 34 columns]

# %%
a_df5['No_show_num'].value_counts()
# Out:
# 0    22333
# 1     8846
# Name: No_show_num, dtype: int64
